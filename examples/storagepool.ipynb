# %%
import copy
import os
import cobra
from tests import TEST_DIR
from diel_models.compartments_creator import CompartmentsCreator

ara_gem_model = os.path.join(TEST_DIR, "data", "AraGEM2010.xml")
non_diel_model = cobra.io.read_sbml_model(ara_gem_model)
non_diel_model_copy = copy.deepcopy(non_diel_model)

# %%
diel_model = CompartmentsCreator(non_diel_model_copy)
diel_model.day_attribution()
DM = diel_model.duplicate()
# Out:
# Ignoring reaction 'Bc1_Night' since it already exists.
# Ignoring reaction 'Bc2_Night' since it already exists.
# Ignoring reaction 'Bc3_Night' since it already exists.
# Ignoring reaction 'Bc4_Night' since it already exists.
# Ignoring reaction 'Bc5_Night' since it already exists.
# Ignoring reaction 'Bc6_Night' since it already exists.
# Ignoring reaction 'Bc7_Night' since it already exists.
# Ignoring reaction 'Bc8_Night' since it already exists.
# Ignoring reaction 'Bc9_Night' since it already exists.
# Ignoring reaction 'Bc10_Night' since it already exists.
# Ignoring reaction 'Bc11_Night' since it already exists.
# Ignoring reaction 'Bc12_Night' since it already exists.
# Ignoring reaction 'Bc13_Night' since it already exists.
# Ignoring reaction 'Bc14_Night' since it already exists.
# Ignoring reaction 'Bc15_Night' since it already exists.
# Ignoring reaction 'Bc16_Night' since it already exists.
# Ignoring reaction 'Bc17_Night' since it already exists.
# Ignoring reaction 'Bc18_Night' since it already exists.
# Ignoring reaction 'Bc19_Night' since it already exists.
# Ignoring reaction 'Bc20_Night' since it already exists.
# Ignoring reaction 'Bc21_Night' since it already exists.
# Ignoring reaction 'Bc22_Night' since it already exists.
# Ignoring reaction 'Bc23_Night' since it already exists.
# Ignoring reaction 'Bc24_Night' since it already exists.
# Ignoring reaction 'Bc25_Night' since it already exists.
# Ignoring reaction 'Bc26_Night' since it already exists.
# Ignoring reaction 'Bc27_Night' since it already exists.
# Ignoring reaction 'Bc28_Night' since it already exists.
# Ignoring reaction 'Bc29_Night' since it already exists.
# Ignoring reaction 'Bc30_Night' since it already exists.
# Ignoring reaction 'Bc31_Night' since it already exists.
# Ignoring reaction 'Bc32_Night' since it already exists.
# Ignoring reaction 'Bc33_Night' since it already exists.
# Ignoring reaction 'Bc34_Night' since it already exists.
# Ignoring reaction 'Bc35_Night' since it already exists.
# Ignoring reaction 'Bc36_Night' since it already exists.
# Ignoring reaction 'Bc37_Night' since it already exists.
# Ignoring reaction 'Bc38_Night' since it already exists.
# Ignoring reaction 'V0001_Night' since it already exists.
# Ignoring reaction 'V0002_Night' since it already exists.
# Ignoring reaction 'V0003_Night' since it already exists.
# Ignoring reaction 'V0004_Night' since it already exists.
# Ignoring reaction 'V0005_Night' since it already exists.
# Ignoring reaction 'V0006_Night' since it already exists.
# Ignoring reaction 'V0007_Night' since it already exists.
# Ignoring reaction 'V0008_Night' since it already exists.
# Ignoring reaction 'BIO_L_Night' since it already exists.
# Ignoring reaction 'Ex1_Night' since it already exists.
# Ignoring reaction 'Ex2_Night' since it already exists.
# Ignoring reaction 'Ex3_Night' since it already exists.
# Ignoring reaction 'Ex4_Night' since it already exists.
# Ignoring reaction 'Ex5_Night' since it already exists.
# Ignoring reaction 'Ex6_Night' since it already exists.
# Ignoring reaction 'Ex7_Night' since it already exists.
# Ignoring reaction 'Ex8_Night' since it already exists.
# Ignoring reaction 'Ex9_Night' since it already exists.
# Ignoring reaction 'Ex10_Night' since it already exists.
# Ignoring reaction 'Ex11_Night' since it already exists.
# Ignoring reaction 'Ex12_Night' since it already exists.
# Ignoring reaction 'Ex13_Night' since it already exists.
# Ignoring reaction 'Ex14_Night' since it already exists.
# Ignoring reaction 'Ex15_Night' since it already exists.
# Ignoring reaction 'Ex16_Night' since it already exists.
# Ignoring reaction 'Ex17_Night' since it already exists.
# Ignoring reaction 'Ex18_Night' since it already exists.
# Ignoring reaction 'TCM1_Night' since it already exists.
# Ignoring reaction 'TCM2_Night' since it already exists.
# Ignoring reaction 'TCM3_Night' since it already exists.
# Ignoring reaction 'TCM4_Night' since it already exists.
# Ignoring reaction 'TCM5_Night' since it already exists.
# Ignoring reaction 'TCM6_Night' since it already exists.
# Ignoring reaction 'TCM7_Night' since it already exists.
# Ignoring reaction 'TCM8_Night' since it already exists.
# Ignoring reaction 'TCM9_Night' since it already exists.
# Ignoring reaction 'TCM10_Night' since it already exists.
# Ignoring reaction 'TCM11_Night' since it already exists.
# Ignoring reaction 'TCM12_Night' since it already exists.
# Ignoring reaction 'TCM13_Night' since it already exists.
# Ignoring reaction 'TCM16_Night' since it already exists.
# Ignoring reaction 'TCM17_Night' since it already exists.
# Ignoring reaction 'TCM18_Night' since it already exists.
# Ignoring reaction 'TCM19_Night' since it already exists.
# Ignoring reaction 'TCM20_Night' since it already exists.
# Ignoring reaction 'TCM21_Night' since it already exists.
# Ignoring reaction 'TCM22_Night' since it already exists.
# Ignoring reaction 'TCM26_Night' since it already exists.
# Ignoring reaction 'TCM27_Night' since it already exists.
# Ignoring reaction 'TCM28_Night' since it already exists.
# Ignoring reaction 'TCM29_Night' since it already exists.
# Ignoring reaction 'TCM31_Night' since it already exists.
# Ignoring reaction 'TCM32_Night' since it already exists.
# Ignoring reaction 'TCP1_Night' since it already exists.
# Ignoring reaction 'TCP2_Night' since it already exists.
# Ignoring reaction 'TCP3_Night' since it already exists.
# Ignoring reaction 'TCP4_Night' since it already exists.
# Ignoring reaction 'TCP5_Night' since it already exists.
# Ignoring reaction 'TCP6_Night' since it already exists.
# Ignoring reaction 'TCP7_Night' since it already exists.
# Ignoring reaction 'TCP8_Night' since it already exists.
# Ignoring reaction 'TCP9_Night' since it already exists.
# Ignoring reaction 'TCP10_Night' since it already exists.
# Ignoring reaction 'TCP11_Night' since it already exists.
# Ignoring reaction 'TCP12_Night' since it already exists.
# Ignoring reaction 'TCP13_Night' since it already exists.
# Ignoring reaction 'TCP14_Night' since it already exists.
# Ignoring reaction 'TCP15_Night' since it already exists.
# Ignoring reaction 'TCP16_Night' since it already exists.
# Ignoring reaction 'TCP17_Night' since it already exists.
# Ignoring reaction 'TCP18_Night' since it already exists.
# Ignoring reaction 'TCP19_Night' since it already exists.
# Ignoring reaction 'TCP20_Night' since it already exists.
# Ignoring reaction 'TCP21_Night' since it already exists.
# Ignoring reaction 'TCP22_Night' since it already exists.
# Ignoring reaction 'TCP23_Night' since it already exists.
# Ignoring reaction 'TCP24_Night' since it already exists.
# Ignoring reaction 'TCP25_Night' since it already exists.
# Ignoring reaction 'TCP26_Night' since it already exists.
# Ignoring reaction 'TCP27_Night' since it already exists.
# Ignoring reaction 'TCP29_Night' since it already exists.
# Ignoring reaction 'TCP30_Night' since it already exists.
# Ignoring reaction 'TCP31_Night' since it already exists.
# Ignoring reaction 'TCV1_Night' since it already exists.
# Ignoring reaction 'TCV2_Night' since it already exists.
# Ignoring reaction 'TCV3_Night' since it already exists.
# Ignoring reaction 'TCV4_Night' since it already exists.
# Ignoring reaction 'TCV5_Night' since it already exists.
# Ignoring reaction 'TCX1_Night' since it already exists.
# Ignoring reaction 'TCX2_Night' since it already exists.
# Ignoring reaction 'TCX3_Night' since it already exists.
# Ignoring reaction 'TCX4_Night' since it already exists.
# Ignoring reaction 'TCX5_Night' since it already exists.
# Ignoring reaction 'TCX6_Night' since it already exists.
# Ignoring reaction 'TCX7_Night' since it already exists.
# Ignoring reaction 'TCX8_Night' since it already exists.
# Ignoring reaction 'TCX9_Night' since it already exists.
# Ignoring reaction 'TCX10_Night' since it already exists.
# Ignoring reaction 'TCX11_Night' since it already exists.
# Ignoring reaction 'TCX12_Night' since it already exists.
# Ignoring reaction 'TCX13_Night' since it already exists.
# Ignoring reaction 'TCX14_Night' since it already exists.
# Ignoring reaction 'TCX15_Night' since it already exists.
# Ignoring reaction 'TCX16_Night' since it already exists.
# Ignoring reaction 'TCX17_Night' since it already exists.
# Ignoring reaction 'TCX18_Night' since it already exists.
# Ignoring reaction 'TCX19_Night' since it already exists.
# Ignoring reaction 'R00095_tmx_Night' since it already exists.
# Ignoring reaction 'R00644_tmx_Night' since it already exists.
# Ignoring reaction 'R00006_c_Night' since it already exists.
# Ignoring reaction 'R00010_c_Night' since it already exists.
# Ignoring reaction 'R00014_c_Night' since it already exists.
# Ignoring reaction 'R00021_p_Night' since it already exists.
# Ignoring reaction 'R00022_c_Night' since it already exists.
# Ignoring reaction 'R00024_p_Night' since it already exists.
# Ignoring reaction 'R00026_c_Night' since it already exists.
# Ignoring reaction 'R00028_p_Night' since it already exists.
# Ignoring reaction 'R00028_c_Night' since it already exists.
# Ignoring reaction 'R00036_c_Night' since it already exists.
# Ignoring reaction 'R00047_c_Night' since it already exists.
# Ignoring reaction 'R00066_c_Night' since it already exists.
# Ignoring reaction 'R00068_c_Night' since it already exists.
# Ignoring reaction 'R00084_c_Night' since it already exists.
# Ignoring reaction 'R00086_c_Night' since it already exists.
# Ignoring reaction 'R00095_c_Night' since it already exists.
# Ignoring reaction 'R00100_c_Night' since it already exists.
# Ignoring reaction 'R00114_c_Night' since it already exists.
# Ignoring reaction 'R00115_c_Night' since it already exists.
# Ignoring reaction 'R00127_c_Night' since it already exists.
# Ignoring reaction 'R00130_c_Night' since it already exists.
# Ignoring reaction 'R00131_c_Night' since it already exists.
# Ignoring reaction 'R00132N_c_Night' since it already exists.
# Ignoring reaction 'R00132N_m_Night' since it already exists.
# Ignoring reaction 'R00132N_p_Night' since it already exists.
# Ignoring reaction 'R00135_c_Night' since it already exists.
# Ignoring reaction 'R00156_c_Night' since it already exists.
# Ignoring reaction 'R00174_c_Night' since it already exists.
# Ignoring reaction 'R00177_c_Night' since it already exists.
# Ignoring reaction 'R00178_c_Night' since it already exists.
# Ignoring reaction 'R00179_c_Night' since it already exists.
# Ignoring reaction 'R00181_c_Night' since it already exists.
# Ignoring reaction 'R00183_c_Night' since it already exists.
# Ignoring reaction 'R00185_c_Night' since it already exists.
# Ignoring reaction 'R00187_c_Night' since it already exists.
# Ignoring reaction 'R00190_c_Night' since it already exists.
# Ignoring reaction 'R00192_c_Night' since it already exists.
# Ignoring reaction 'R00200_c_Night' since it already exists.
# Ignoring reaction 'R00200_p_Night' since it already exists.
# Ignoring reaction 'R00206_p_Night' since it already exists.
# Ignoring reaction 'R00209_p_Night' since it already exists.
# Ignoring reaction 'R00209_m_Night' since it already exists.
# Ignoring reaction 'R00214_c_Night' since it already exists.
# Ignoring reaction 'R00216_p_Night' since it already exists.
# Ignoring reaction 'R00219_c_Night' since it already exists.
# Ignoring reaction 'R00233_c_Night' since it already exists.
# Ignoring reaction 'R00236_c_Night' since it already exists.
# Ignoring reaction 'R00236_m_Night' since it already exists.
# Ignoring reaction 'R00238_c_Night' since it already exists.
# Ignoring reaction 'R00238_m_Night' since it already exists.
# Ignoring reaction 'R00238_p_Night' since it already exists.
# Ignoring reaction 'R00238_x_Night' since it already exists.
# Ignoring reaction 'R00239_c_Night' since it already exists.
# Ignoring reaction 'R00243_c_Night' since it already exists.
# Ignoring reaction 'R00243_m_Night' since it already exists.
# Ignoring reaction 'R00251_c_Night' since it already exists.
# Ignoring reaction 'R00253_c_Night' since it already exists.
# Ignoring reaction 'R00253_m_Night' since it already exists.
# Ignoring reaction 'R00253_p_Night' since it already exists.
# Ignoring reaction 'R00257_c_Night' since it already exists.
# Ignoring reaction 'R00258_c_Night' since it already exists.
# Ignoring reaction 'R00258_p_Night' since it already exists.
# Ignoring reaction 'R00259_c_Night' since it already exists.
# Ignoring reaction 'R00261_c_Night' since it already exists.
# Ignoring reaction 'R00267_m_Night' since it already exists.
# Ignoring reaction 'R00286_c_Night' since it already exists.
# Ignoring reaction 'R00289_c_Night' since it already exists.
# Ignoring reaction 'R00291_c_Night' since it already exists.
# Ignoring reaction 'R00308_c_Night' since it already exists.
# Ignoring reaction 'R00310_c_Night' since it already exists.
# Ignoring reaction 'R00316_m_Night' since it already exists.
# Ignoring reaction 'R00330_c_Night' since it already exists.
# Ignoring reaction 'R00332_c_Night' since it already exists.
# Ignoring reaction 'R00341_c_Night' since it already exists.
# Ignoring reaction 'R00342_c_Night' since it already exists.
# Ignoring reaction 'R00342_m_Night' since it already exists.
# Ignoring reaction 'R00342_x_Night' since it already exists.
# Ignoring reaction 'R00342_p_Night' since it already exists.
# Ignoring reaction 'R00343_m_Night' since it already exists.
# Ignoring reaction 'R00343_p_Night' since it already exists.
# Ignoring reaction 'R00345_c_Night' since it already exists.
# Ignoring reaction 'R00351_x_Night' since it already exists.
# Ignoring reaction 'R00351_m_Night' since it already exists.
# Ignoring reaction 'R00352_c_Night' since it already exists.
# Ignoring reaction 'R00355_c_Night' since it already exists.
# Ignoring reaction 'R00355_m_Night' since it already exists.
# Ignoring reaction 'R00355_p_Night' since it already exists.
# Ignoring reaction 'R00369_c_Night' since it already exists.
# Ignoring reaction 'R00415_c_Night' since it already exists.
# Ignoring reaction 'R00425_c_Night' since it already exists.
# Ignoring reaction 'R00429_c_Night' since it already exists.
# Ignoring reaction 'R00451_c_Night' since it already exists.
# Ignoring reaction 'R00472_x_Night' since it already exists.
# Ignoring reaction 'R00475_x_Night' since it already exists.
# Ignoring reaction 'R00479_x_Night' since it already exists.
# Ignoring reaction 'R00480_c_Night' since it already exists.
# Ignoring reaction 'R00481_c_Night' since it already exists.
# Ignoring reaction 'R00485_c_Night' since it already exists.
# Ignoring reaction 'R00489_c_Night' since it already exists.
# Ignoring reaction 'R00494_c_Night' since it already exists.
# Ignoring reaction 'R00497_c_Night' since it already exists.
# Ignoring reaction 'R00502_c_Night' since it already exists.
# Ignoring reaction 'R00508_c_Night' since it already exists.
# Ignoring reaction 'R00509_c_Night' since it already exists.
# Ignoring reaction 'R00511_c_Night' since it already exists.
# Ignoring reaction 'R00519_x_Night' since it already exists.
# Ignoring reaction 'R00529_c_Night' since it already exists.
# Ignoring reaction 'R00533_c_Night' since it already exists.
# Ignoring reaction 'R00540_c_Night' since it already exists.
# Ignoring reaction 'R00548_c_Night' since it already exists.
# Ignoring reaction 'R00549_c_Night' since it already exists.
# Ignoring reaction 'R00551_c_Night' since it already exists.
# Ignoring reaction 'R00566_c_Night' since it already exists.
# Ignoring reaction 'R00570_c_Night' since it already exists.
# Ignoring reaction 'R00571_c_Night' since it already exists.
# Ignoring reaction 'R00573_c_Night' since it already exists.
# Ignoring reaction 'R00575_c_Night' since it already exists.
# Ignoring reaction 'R00575_m_Night' since it already exists.
# Ignoring reaction 'R00578_c_Night' since it already exists.
# Ignoring reaction 'R00586_c_Night' since it already exists.
# Ignoring reaction 'R00588_x_Night' since it already exists.
# Ignoring reaction 'R00602_c_Night' since it already exists.
# Ignoring reaction 'R00610_c_Night' since it already exists.
# Ignoring reaction 'R00615_c_Night' since it already exists.
# Ignoring reaction 'R00616_c_Night' since it already exists.
# Ignoring reaction 'R00619_c_Night' since it already exists.
# Ignoring reaction 'R00621_m_Night' since it already exists.
# Ignoring reaction 'R00623_c_Night' since it already exists.
# Ignoring reaction 'R00631_c_Night' since it already exists.
# Ignoring reaction 'R00640_c_Night' since it already exists.
# Ignoring reaction 'R00650_c_Night' since it already exists.
# Ignoring reaction 'R00658_c_Night' since it already exists.
# Ignoring reaction 'R00658_p_Night' since it already exists.
# Ignoring reaction 'R00667_c_Night' since it already exists.
# Ignoring reaction 'R00669_c_Night' since it already exists.
# Ignoring reaction 'R00691_c_Night' since it already exists.
# Ignoring reaction 'R00694_c_Night' since it already exists.
# Ignoring reaction 'R00697_c_Night' since it already exists.
# Ignoring reaction 'R00698_c_Night' since it already exists.
# Ignoring reaction 'R00702_c_Night' since it already exists.
# Ignoring reaction 'R00703_c_Night' since it already exists.
# Ignoring reaction 'R00705_c_Night' since it already exists.
# Ignoring reaction 'R00709_m_Night' since it already exists.
# Ignoring reaction 'R00710_c_Night' since it already exists.
# Ignoring reaction 'R00713_c_Night' since it already exists.
# Ignoring reaction 'R00722_c_Night' since it already exists.
# Ignoring reaction 'R00734_c_Night' since it already exists.
# Ignoring reaction 'R00736_c_Night' since it already exists.
# Ignoring reaction 'R00737_c_Night' since it already exists.
# Ignoring reaction 'R00742_c_Night' since it already exists.
# Ignoring reaction 'R00742_p_Night' since it already exists.
# Ignoring reaction 'R00750_c_Night' since it already exists.
# Ignoring reaction 'R00754_c_Night' since it already exists.
# Ignoring reaction 'R00755_c_Night' since it already exists.
# Ignoring reaction 'R00762_c_Night' since it already exists.
# Ignoring reaction 'R00762_p_Night' since it already exists.
# Ignoring reaction 'R00766_c_Night' since it already exists.
# Ignoring reaction 'R00768_c_Night' since it already exists.
# Ignoring reaction 'R00782_c_Night' since it already exists.
# Ignoring reaction 'R00790_c_Night' since it already exists.
# Ignoring reaction 'R00790_p_Night' since it already exists.
# Ignoring reaction 'R00794_c_Night' since it already exists.
# Ignoring reaction 'R00801_c_Night' since it already exists.
# Ignoring reaction 'R00802_c_Night' since it already exists.
# Ignoring reaction 'R00806_c_Night' since it already exists.
# Ignoring reaction 'R00829_c_Night' since it already exists.
# Ignoring reaction 'R00840_c_Night' since it already exists.
# Ignoring reaction 'R00842_c_Night' since it already exists.
# Ignoring reaction 'R00847_c_Night' since it already exists.
# Ignoring reaction 'R00848_c_Night' since it already exists.
# Ignoring reaction 'R00851_c_Night' since it already exists.
# Ignoring reaction 'R00859_c_Night' since it already exists.
# Ignoring reaction 'R00867_c_Night' since it already exists.
# Ignoring reaction 'R00875_c_Night' since it already exists.
# Ignoring reaction 'R00883_c_Night' since it already exists.
# Ignoring reaction 'R00887N_c_Night' since it already exists.
# Ignoring reaction 'R00888_c_Night' since it already exists.
# Ignoring reaction 'R00890_c_Night' since it already exists.
# Ignoring reaction 'R00894_c_Night' since it already exists.
# Ignoring reaction 'R00896_c_Night' since it already exists.
# Ignoring reaction 'R00897_c_Night' since it already exists.
# Ignoring reaction 'R00899_c_Night' since it already exists.
# Ignoring reaction 'R00904_c_Night' since it already exists.
# Ignoring reaction 'R00905_c_Night' since it already exists.
# Ignoring reaction 'R00924_c_Night' since it already exists.
# Ignoring reaction 'R00926_c_Night' since it already exists.
# Ignoring reaction 'R00927_c_Night' since it already exists.
# Ignoring reaction 'R00935_c_Night' since it already exists.
# Ignoring reaction 'R00936_c_Night' since it already exists.
# Ignoring reaction 'R00937_c_Night' since it already exists.
# Ignoring reaction 'R00942_c_Night' since it already exists.
# Ignoring reaction 'R00943_c_Night' since it already exists.
# Ignoring reaction 'R00944_c_Night' since it already exists.
# Ignoring reaction 'R00945_c_Night' since it already exists.
# Ignoring reaction 'R00945_m_Night' since it already exists.
# Ignoring reaction 'R00948_c_Night' since it already exists.
# Ignoring reaction 'R00948_p_Night' since it already exists.
# Ignoring reaction 'R00959_p_Night' since it already exists.
# Ignoring reaction 'R00959_c_Night' since it already exists.
# Ignoring reaction 'R00963_c_Night' since it already exists.
# Ignoring reaction 'R00965_c_Night' since it already exists.
# Ignoring reaction 'R00966_c_Night' since it already exists.
# Ignoring reaction 'R00985_c_Night' since it already exists.
# Ignoring reaction 'R00986_c_Night' since it already exists.
# Ignoring reaction 'R00996_c_Night' since it already exists.
# Ignoring reaction 'R00999_c_Night' since it already exists.
# Ignoring reaction 'R01000_c_Night' since it already exists.
# Ignoring reaction 'R01004_c_Night' since it already exists.
# Ignoring reaction 'R01005_c_Night' since it already exists.
# Ignoring reaction 'R01009_c_Night' since it already exists.
# Ignoring reaction 'R01015_c_Night' since it already exists.
# Ignoring reaction 'R01015_p_Night' since it already exists.
# Ignoring reaction 'R01030_c_Night' since it already exists.
# Ignoring reaction 'R01036_c_Night' since it already exists.
# Ignoring reaction 'R01049_c_Night' since it already exists.
# Ignoring reaction 'R01051_c_Night' since it already exists.
# Ignoring reaction 'R01055_c_Night' since it already exists.
# Ignoring reaction 'R01056_c_Night' since it already exists.
# Ignoring reaction 'R01056_p_Night' since it already exists.
# Ignoring reaction 'R01057_c_Night' since it already exists.
# Ignoring reaction 'R01061_c_Night' since it already exists.
# Ignoring reaction 'R01061_p_Night' since it already exists.
# Ignoring reaction 'R01063_p_Night' since it already exists.
# Ignoring reaction 'R01070N_c_Night' since it already exists.
# Ignoring reaction 'R01070N_p_Night' since it already exists.
# Ignoring reaction 'R01072_c_Night' since it already exists.
# Ignoring reaction 'R01073_c_Night' since it already exists.
# Ignoring reaction 'R01078N_c_Night' since it already exists.
# Ignoring reaction 'R01082_m_Night' since it already exists.
# Ignoring reaction 'R01083_c_Night' since it already exists.
# Ignoring reaction 'R01086_c_Night' since it already exists.
# Ignoring reaction 'R01090_c_Night' since it already exists.
# Ignoring reaction 'R01092_c_Night' since it already exists.
# Ignoring reaction 'R01101_c_Night' since it already exists.
# Ignoring reaction 'R01103_c_Night' since it already exists.
# Ignoring reaction 'R01104_c_Night' since it already exists.
# Ignoring reaction 'R01105_c_Night' since it already exists.
# Ignoring reaction 'R01121_c_Night' since it already exists.
# Ignoring reaction 'R01123_c_Night' since it already exists.
# Ignoring reaction 'R01126_c_Night' since it already exists.
# Ignoring reaction 'R01130_c_Night' since it already exists.
# Ignoring reaction 'R01132_c_Night' since it already exists.
# Ignoring reaction 'R01135_c_Night' since it already exists.
# Ignoring reaction 'R01137_c_Night' since it already exists.
# Ignoring reaction 'R01151_c_Night' since it already exists.
# Ignoring reaction 'R01159_c_Night' since it already exists.
# Ignoring reaction 'R01175N_x_Night' since it already exists.
# Ignoring reaction 'R01177_x_Night' since it already exists.
# Ignoring reaction 'R01185_c_Night' since it already exists.
# Ignoring reaction 'R01186_c_Night' since it already exists.
# Ignoring reaction 'R01187_c_Night' since it already exists.
# Ignoring reaction 'R01206_c_Night' since it already exists.
# Ignoring reaction 'R01209_c_Night' since it already exists.
# Ignoring reaction 'R01213_c_Night' since it already exists.
# Ignoring reaction 'R01214_c_Night' since it already exists.
# Ignoring reaction 'R01220_c_Night' since it already exists.
# Ignoring reaction 'R01221_c_Night' since it already exists.
# Ignoring reaction 'R01221_m_Night' since it already exists.
# Ignoring reaction 'R01222_c_Night' since it already exists.
# Ignoring reaction 'R01224_c_Night' since it already exists.
# Ignoring reaction 'R01226_c_Night' since it already exists.
# Ignoring reaction 'R01227_c_Night' since it already exists.
# Ignoring reaction 'R01229_c_Night' since it already exists.
# Ignoring reaction 'R01230_c_Night' since it already exists.
# Ignoring reaction 'R01231_c_Night' since it already exists.
# Ignoring reaction 'R01248_c_Night' since it already exists.
# Ignoring reaction 'R01252_c_Night' since it already exists.
# Ignoring reaction 'R01262_c_Night' since it already exists.
# Ignoring reaction 'R01279_x_Night' since it already exists.
# Ignoring reaction 'R01280_x_Night' since it already exists.
# Ignoring reaction 'R01281_c_Night' since it already exists.
# Ignoring reaction 'R01286_c_Night' since it already exists.
# Ignoring reaction 'R01287_c_Night' since it already exists.
# Ignoring reaction 'R01288_c_Night' since it already exists.
# Ignoring reaction 'R01303_c_Night' since it already exists.
# Ignoring reaction 'R01310_c_Night' since it already exists.
# Ignoring reaction 'R01324_m_Night' since it already exists.
# Ignoring reaction 'R01324_c_Night' since it already exists.
# Ignoring reaction 'R01325_x_Night' since it already exists.
# Ignoring reaction 'R01326_c_Night' since it already exists.
# Ignoring reaction 'R01329_c_Night' since it already exists.
# Ignoring reaction 'R01354_c_Night' since it already exists.
# Ignoring reaction 'R01360_c_Night' since it already exists.
# Ignoring reaction 'R01364_c_Night' since it already exists.
# Ignoring reaction 'R01372_c_Night' since it already exists.
# Ignoring reaction 'R01373_c_Night' since it already exists.
# Ignoring reaction 'R01373N_c_Night' since it already exists.
# Ignoring reaction 'R01397_c_Night' since it already exists.
# Ignoring reaction 'R01398_c_Night' since it already exists.
# Ignoring reaction 'R01398_m_Night' since it already exists.
# Ignoring reaction 'R01398_p_Night' since it already exists.
# Ignoring reaction 'R01409_c_Night' since it already exists.
# Ignoring reaction 'R01451_c_Night' since it already exists.
# Ignoring reaction 'R01466_c_Night' since it already exists.
# Ignoring reaction 'R01470_c_Night' since it already exists.
# Ignoring reaction 'R01495_c_Night' since it already exists.
# Ignoring reaction 'R01512_c_Night' since it already exists.
# Ignoring reaction 'R01512_p_Night' since it already exists.
# Ignoring reaction 'R01513_c_Night' since it already exists.
# Ignoring reaction 'R01518_c_Night' since it already exists.
# Ignoring reaction 'R01518_p_Night' since it already exists.
# Ignoring reaction 'R01523_c_Night' since it already exists.
# Ignoring reaction 'R01523_p_Night' since it already exists.
# Ignoring reaction 'R01528_c_Night' since it already exists.
# Ignoring reaction 'R01528_p_Night' since it already exists.
# Ignoring reaction 'R01529_c_Night' since it already exists.
# Ignoring reaction 'R01529_p_Night' since it already exists.
# Ignoring reaction 'R01547_c_Night' since it already exists.
# Ignoring reaction 'R01560_c_Night' since it already exists.
# Ignoring reaction 'R01567_c_Night' since it already exists.
# Ignoring reaction 'R01569_c_Night' since it already exists.
# Ignoring reaction 'R01600_c_Night' since it already exists.
# Ignoring reaction 'R01602_c_Night' since it already exists.
# Ignoring reaction 'R01613_c_Night' since it already exists.
# Ignoring reaction 'R01616_c_Night' since it already exists.
# Ignoring reaction 'R01624_c_Night' since it already exists.
# Ignoring reaction 'R01624_p_Night' since it already exists.
# Ignoring reaction 'R01626_c_Night' since it already exists.
# Ignoring reaction 'R01626_p_Night' since it already exists.
# Ignoring reaction 'R01641_c_Night' since it already exists.
# Ignoring reaction 'R01641_p_Night' since it already exists.
# Ignoring reaction 'R01645_c_Night' since it already exists.
# Ignoring reaction 'R01655_c_Night' since it already exists.
# Ignoring reaction 'R01658_c_Night' since it already exists.
# Ignoring reaction 'R01663_c_Night' since it already exists.
# Ignoring reaction 'R01664_c_Night' since it already exists.
# Ignoring reaction 'R01678_c_Night' since it already exists.
# Ignoring reaction 'R01679_c_Night' since it already exists.
# Ignoring reaction 'R01682_c_Night' since it already exists.
# Ignoring reaction 'R01687_c_Night' since it already exists.
# Ignoring reaction 'R01701_c_Night' since it already exists.
# Ignoring reaction 'R01702_c_Night' since it already exists.
# Ignoring reaction 'R01714_c_Night' since it already exists.
# Ignoring reaction 'R01715_c_Night' since it already exists.
# Ignoring reaction 'R01717_c_Night' since it already exists.
# Ignoring reaction 'R01719_c_Night' since it already exists.
# Ignoring reaction 'R01736_c_Night' since it already exists.
# Ignoring reaction 'R01737_c_Night' since it already exists.
# Ignoring reaction 'R01752_c_Night' since it already exists.
# Ignoring reaction 'R01768_c_Night' since it already exists.
# Ignoring reaction 'R01769_c_Night' since it already exists.
# Ignoring reaction 'R01771_c_Night' since it already exists.
# Ignoring reaction 'R01773_c_Night' since it already exists.
# Ignoring reaction 'R01786_c_Night' since it already exists.
# Ignoring reaction 'R01799_c_Night' since it already exists.
# Ignoring reaction 'R01801_c_Night' since it already exists.
# Ignoring reaction 'R01802_c_Night' since it already exists.
# Ignoring reaction 'R01818_c_Night' since it already exists.
# Ignoring reaction 'R01819_c_Night' since it already exists.
# Ignoring reaction 'R01826_c_Night' since it already exists.
# Ignoring reaction 'R01827_c_Night' since it already exists.
# Ignoring reaction 'R01827_p_Night' since it already exists.
# Ignoring reaction 'R01829_c_Night' since it already exists.
# Ignoring reaction 'R01829_p_Night' since it already exists.
# Ignoring reaction 'R01830_c_Night' since it already exists.
# Ignoring reaction 'R01830_p_Night' since it already exists.
# Ignoring reaction 'R01845_c_Night' since it already exists.
# Ignoring reaction 'R01845_p_Night' since it already exists.
# Ignoring reaction 'R01857_c_Night' since it already exists.
# Ignoring reaction 'R01867_c_Night' since it already exists.
# Ignoring reaction 'R01870_c_Night' since it already exists.
# Ignoring reaction 'R01878_c_Night' since it already exists.
# Ignoring reaction 'R01887_c_Night' since it already exists.
# Ignoring reaction 'R01900_x_Night' since it already exists.
# Ignoring reaction 'R01909_c_Night' since it already exists.
# Ignoring reaction 'R01920_c_Night' since it already exists.
# Ignoring reaction 'R01933_c_Night' since it already exists.
# Ignoring reaction 'R01940_c_Night' since it already exists.
# Ignoring reaction 'R01942_c_Night' since it already exists.
# Ignoring reaction 'R01943_c_Night' since it already exists.
# Ignoring reaction 'R01954_c_Night' since it already exists.
# Ignoring reaction 'R01961_c_Night' since it already exists.
# Ignoring reaction 'R01966_c_Night' since it already exists.
# Ignoring reaction 'R01968_c_Night' since it already exists.
# Ignoring reaction 'R01976_c_Night' since it already exists.
# Ignoring reaction 'R01978_c_Night' since it already exists.
# Ignoring reaction 'R01982_c_Night' since it already exists.
# Ignoring reaction 'R01986_c_Night' since it already exists.
# Ignoring reaction 'R01993_c_Night' since it already exists.
# Ignoring reaction 'R02003_c_Night' since it already exists.
# Ignoring reaction 'R02006_c_Night' since it already exists.
# Ignoring reaction 'R02016_c_Night' since it already exists.
# Ignoring reaction 'R02017_c_Night' since it already exists.
# Ignoring reaction 'R02018_c_Night' since it already exists.
# Ignoring reaction 'R02019_c_Night' since it already exists.
# Ignoring reaction 'R02024_c_Night' since it already exists.
# Ignoring reaction 'R02026_c_Night' since it already exists.
# Ignoring reaction 'R02035_c_Night' since it already exists.
# Ignoring reaction 'R02035_p_Night' since it already exists.
# Ignoring reaction 'R02037_c_Night' since it already exists.
# Ignoring reaction 'R02038_c_Night' since it already exists.
# Ignoring reaction 'R02051_c_Night' since it already exists.
# Ignoring reaction 'R02055_c_Night' since it already exists.
# Ignoring reaction 'R02057_c_Night' since it already exists.
# Ignoring reaction 'R02058_c_Night' since it already exists.
# Ignoring reaction 'R02061_c_Night' since it already exists.
# Ignoring reaction 'R02068_c_Night' since it already exists.
# Ignoring reaction 'R02080_c_Night' since it already exists.
# Ignoring reaction 'R02082_c_Night' since it already exists.
# Ignoring reaction 'R02086_c_Night' since it already exists.
# Ignoring reaction 'R02088_c_Night' since it already exists.
# Ignoring reaction 'R02090_c_Night' since it already exists.
# Ignoring reaction 'R02093_c_Night' since it already exists.
# Ignoring reaction 'R02094_c_Night' since it already exists.
# Ignoring reaction 'R02098_c_Night' since it already exists.
# Ignoring reaction 'R02099_c_Night' since it already exists.
# Ignoring reaction 'R02100_c_Night' since it already exists.
# Ignoring reaction 'R02101_c_Night' since it already exists.
# Ignoring reaction 'R02103_c_Night' since it already exists.
# Ignoring reaction 'R02106_c_Night' since it already exists.
# Ignoring reaction 'R02107_c_Night' since it already exists.
# Ignoring reaction 'R02108_p_Night' since it already exists.
# Ignoring reaction 'R02110_p_Night' since it already exists.
# Ignoring reaction 'R02111_p_Night' since it already exists.
# Ignoring reaction 'R02112N_p_Night' since it already exists.
# Ignoring reaction 'R02142_c_Night' since it already exists.
# Ignoring reaction 'R02150_c_Night' since it already exists.
# Ignoring reaction 'R02157_c_Night' since it already exists.
# Ignoring reaction 'R02158_c_Night' since it already exists.
# Ignoring reaction 'R02160_c_Night' since it already exists.
# Ignoring reaction 'R02164_p_Night' since it already exists.
# Ignoring reaction 'R02166_c_Night' since it already exists.
# Ignoring reaction 'R02173_c_Night' since it already exists.
# Ignoring reaction 'R02175_c_Night' since it already exists.
# Ignoring reaction 'R02194_c_Night' since it already exists.
# Ignoring reaction 'R02198_c_Night' since it already exists.
# Ignoring reaction 'R02199_c_Night' since it already exists.
# Ignoring reaction 'R02221_c_Night' since it already exists.
# Ignoring reaction 'R02235_c_Night' since it already exists.
# Ignoring reaction 'R02237_c_Night' since it already exists.
# Ignoring reaction 'R02240_c_Night' since it already exists.
# Ignoring reaction 'R02241_c_Night' since it already exists.
# Ignoring reaction 'R02245_c_Night' since it already exists.
# Ignoring reaction 'R02253_c_Night' since it already exists.
# Ignoring reaction 'R02255_c_Night' since it already exists.
# Ignoring reaction 'R02269_c_Night' since it already exists.
# Ignoring reaction 'R02272_c_Night' since it already exists.
# Ignoring reaction 'R02282_c_Night' since it already exists.
# Ignoring reaction 'R02283_c_Night' since it already exists.
# Ignoring reaction 'R02291_c_Night' since it already exists.
# Ignoring reaction 'R02292_c_Night' since it already exists.
# Ignoring reaction 'R02300_c_Night' since it already exists.
# Ignoring reaction 'R02301_c_Night' since it already exists.
# Ignoring reaction 'R02320_c_Night' since it already exists.
# Ignoring reaction 'R02323_c_Night' since it already exists.
# Ignoring reaction 'R02326_c_Night' since it already exists.
# Ignoring reaction 'R02331_c_Night' since it already exists.
# Ignoring reaction 'R02334_c_Night' since it already exists.
# Ignoring reaction 'R02340_c_Night' since it already exists.
# Ignoring reaction 'R02351_c_Night' since it already exists.
# Ignoring reaction 'R02360_c_Night' since it already exists.
# Ignoring reaction 'R02361_c_Night' since it already exists.
# Ignoring reaction 'R02362_c_Night' since it already exists.
# Ignoring reaction 'R02382_c_Night' since it already exists.
# Ignoring reaction 'R02408_c_Night' since it already exists.
# Ignoring reaction 'R02410_c_Night' since it already exists.
# Ignoring reaction 'R02411_c_Night' since it already exists.
# Ignoring reaction 'R02412_c_Night' since it already exists.
# Ignoring reaction 'R02433_c_Night' since it already exists.
# Ignoring reaction 'R02435_c_Night' since it already exists.
# Ignoring reaction 'R02442_c_Night' since it already exists.
# Ignoring reaction 'R02444_c_Night' since it already exists.
# Ignoring reaction 'R02446_c_Night' since it already exists.
# Ignoring reaction 'R02464_c_Night' since it already exists.
# Ignoring reaction 'R02466_c_Night' since it already exists.
# Ignoring reaction 'R02473_c_Night' since it already exists.
# Ignoring reaction 'R02485_c_Night' since it already exists.
# Ignoring reaction 'R02487_c_Night' since it already exists.
# Ignoring reaction 'R02488_c_Night' since it already exists.
# Ignoring reaction 'R02493_c_Night' since it already exists.
# Ignoring reaction 'R02518_c_Night' since it already exists.
# Ignoring reaction 'R02519_c_Night' since it already exists.
# Ignoring reaction 'R02521_c_Night' since it already exists.
# Ignoring reaction 'R02529_c_Night' since it already exists.
# Ignoring reaction 'R02530_c_Night' since it already exists.
# Ignoring reaction 'R02556_c_Night' since it already exists.
# Ignoring reaction 'R02565_c_Night' since it already exists.
# Ignoring reaction 'R02566_c_Night' since it already exists.
# Ignoring reaction 'R02568_c_Night' since it already exists.
# Ignoring reaction 'R02570N_m_Night' since it already exists.
# Ignoring reaction 'R02571_c_Night' since it already exists.
# Ignoring reaction 'R02581_c_Night' since it already exists.
# Ignoring reaction 'R02593_c_Night' since it already exists.
# Ignoring reaction 'R02596_c_Night' since it already exists.
# Ignoring reaction 'R02613_c_Night' since it already exists.
# Ignoring reaction 'R02619_c_Night' since it already exists.
# Ignoring reaction 'R02649_c_Night' since it already exists.
# Ignoring reaction 'R02661_c_Night' since it already exists.
# Ignoring reaction 'R02662_c_Night' since it already exists.
# Ignoring reaction 'R02670_c_Night' since it already exists.
# Ignoring reaction 'R02671_c_Night' since it already exists.
# Ignoring reaction 'R02678_c_Night' since it already exists.
# Ignoring reaction 'R02691_c_Night' since it already exists.
# Ignoring reaction 'R02719_c_Night' since it already exists.
# Ignoring reaction 'R02722_c_Night' since it already exists.
# Ignoring reaction 'R02735_c_Night' since it already exists.
# Ignoring reaction 'R02736_c_Night' since it already exists.
# Ignoring reaction 'R02736_p_Night' since it already exists.
# Ignoring reaction 'R02737_c_Night' since it already exists.
# Ignoring reaction 'R02739_p_Night' since it already exists.
# Ignoring reaction 'R02739_c_Night' since it already exists.
# Ignoring reaction 'R02740_c_Night' since it already exists.
# Ignoring reaction 'R02740_p_Night' since it already exists.
# Ignoring reaction 'R02750_c_Night' since it already exists.
# Ignoring reaction 'R02756_c_Night' since it already exists.
# Ignoring reaction 'R02771_c_Night' since it already exists.
# Ignoring reaction 'R02778_c_Night' since it already exists.
# Ignoring reaction 'R02811_c_Night' since it already exists.
# Ignoring reaction 'R02832_c_Night' since it already exists.
# Ignoring reaction 'R02834_c_Night' since it already exists.
# Ignoring reaction 'R02869_c_Night' since it already exists.
# Ignoring reaction 'R02872_c_Night' since it already exists.
# Ignoring reaction 'R02873_c_Night' since it already exists.
# Ignoring reaction 'R02874_c_Night' since it already exists.
# Ignoring reaction 'R02886_c_Night' since it already exists.
# Ignoring reaction 'R02887_c_Night' since it already exists.
# Ignoring reaction 'R02912_c_Night' since it already exists.
# Ignoring reaction 'R02918_c_Night' since it already exists.
# Ignoring reaction 'R02926_c_Night' since it already exists.
# Ignoring reaction 'R02940_c_Night' since it already exists.
# Ignoring reaction 'R02946_c_Night' since it already exists.
# Ignoring reaction 'R02952_c_Night' since it already exists.
# Ignoring reaction 'R02957_c_Night' since it already exists.
# Ignoring reaction 'R02984_c_Night' since it already exists.
# Ignoring reaction 'R03008_c_Night' since it already exists.
# Ignoring reaction 'R03024_c_Night' since it already exists.
# Ignoring reaction 'R03026_x_Night' since it already exists.
# Ignoring reaction 'R03038_c_Night' since it already exists.
# Ignoring reaction 'R03045_c_Night' since it already exists.
# Ignoring reaction 'R03050_c_Night' since it already exists.
# Ignoring reaction 'R03051_c_Night' since it already exists.
# Ignoring reaction 'R03055_c_Night' since it already exists.
# Ignoring reaction 'R03057_c_Night' since it already exists.
# Ignoring reaction 'R03083_c_Night' since it already exists.
# Ignoring reaction 'R03084_c_Night' since it already exists.
# Ignoring reaction 'R03087_c_Night' since it already exists.
# Ignoring reaction 'R03093_c_Night' since it already exists.
# Ignoring reaction 'R03104_c_Night' since it already exists.
# Ignoring reaction 'R03123_c_Night' since it already exists.
# Ignoring reaction 'R03124_c_Night' since it already exists.
# Ignoring reaction 'R03126_c_Night' since it already exists.
# Ignoring reaction 'R03132_c_Night' since it already exists.
# Ignoring reaction 'R03139_c_Night' since it already exists.
# Ignoring reaction 'R03140_p_Night' since it already exists.
# Ignoring reaction 'R03172_c_Night' since it already exists.
# Ignoring reaction 'R03174_c_Night' since it already exists.
# Ignoring reaction 'R03182_c_Night' since it already exists.
# Ignoring reaction 'R03194_c_Night' since it already exists.
# Ignoring reaction 'R03197_c_Night' since it already exists.
# Ignoring reaction 'R03199_c_Night' since it already exists.
# Ignoring reaction 'R03200_c_Night' since it already exists.
# Ignoring reaction 'R03217_c_Night' since it already exists.
# Ignoring reaction 'R03220_c_Night' since it already exists.
# Ignoring reaction 'R03222_c_Night' since it already exists.
# Ignoring reaction 'R03223_c_Night' since it already exists.
# Ignoring reaction 'R03231_c_Night' since it already exists.
# Ignoring reaction 'R03243_c_Night' since it already exists.
# Ignoring reaction 'R03245_c_Night' since it already exists.
# Ignoring reaction 'R03254_c_Night' since it already exists.
# Ignoring reaction 'R03260_c_Night' since it already exists.
# Ignoring reaction 'R03269_c_Night' since it already exists.
# Ignoring reaction 'R03270_c_Night' since it already exists.
# Ignoring reaction 'R03283_c_Night' since it already exists.
# Ignoring reaction 'R03284_c_Night' since it already exists.
# Ignoring reaction 'R03291_c_Night' since it already exists.
# Ignoring reaction 'R03313_c_Night' since it already exists.
# Ignoring reaction 'R03316N_m_Night' since it already exists.
# Ignoring reaction 'R03321_c_Night' since it already exists.
# Ignoring reaction 'R03341_c_Night' since it already exists.
# Ignoring reaction 'R03346_c_Night' since it already exists.
# Ignoring reaction 'R03347_c_Night' since it already exists.
# Ignoring reaction 'R03348_c_Night' since it already exists.
# Ignoring reaction 'R03351_c_Night' since it already exists.
# Ignoring reaction 'R03355_c_Night' since it already exists.
# Ignoring reaction 'R03362_c_Night' since it already exists.
# Ignoring reaction 'R03367_c_Night' since it already exists.
# Ignoring reaction 'R03393_c_Night' since it already exists.
# Ignoring reaction 'R03408_c_Night' since it already exists.
# Ignoring reaction 'R03418_c_Night' since it already exists.
# Ignoring reaction 'R03425_m_Night' since it already exists.
# Ignoring reaction 'R03427_c_Night' since it already exists.
# Ignoring reaction 'R03443_c_Night' since it already exists.
# Ignoring reaction 'R03457_c_Night' since it already exists.
# Ignoring reaction 'R03458_c_Night' since it already exists.
# Ignoring reaction 'R03459_c_Night' since it already exists.
# Ignoring reaction 'R03460_c_Night' since it already exists.
# Ignoring reaction 'R03469_c_Night' since it already exists.
# Ignoring reaction 'R03472_c_Night' since it already exists.
# Ignoring reaction 'R03504_c_Night' since it already exists.
# Ignoring reaction 'R03508_c_Night' since it already exists.
# Ignoring reaction 'R03522_c_Night' since it already exists.
# Ignoring reaction 'R03527_c_Night' since it already exists.
# Ignoring reaction 'R03530_c_Night' since it already exists.
# Ignoring reaction 'R03540_c_Night' since it already exists.
# Ignoring reaction 'R03542_c_Night' since it already exists.
# Ignoring reaction 'R03546_c_Night' since it already exists.
# Ignoring reaction 'R03600_c_Night' since it already exists.
# Ignoring reaction 'R03601_c_Night' since it already exists.
# Ignoring reaction 'R03616_c_Night' since it already exists.
# Ignoring reaction 'R03634_c_Night' since it already exists.
# Ignoring reaction 'R03635_c_Night' since it already exists.
# Ignoring reaction 'R03636_c_Night' since it already exists.
# Ignoring reaction 'R03640_c_Night' since it already exists.
# Ignoring reaction 'R03646_c_Night' since it already exists.
# Ignoring reaction 'R03647_c_Night' since it already exists.
# Ignoring reaction 'R03648_c_Night' since it already exists.
# Ignoring reaction 'R03650_c_Night' since it already exists.
# Ignoring reaction 'R03651N_m_Night' since it already exists.
# Ignoring reaction 'R03652N_c_Night' since it already exists.
# Ignoring reaction 'R03654_c_Night' since it already exists.
# Ignoring reaction 'R03655_c_Night' since it already exists.
# Ignoring reaction 'R03656_c_Night' since it already exists.
# Ignoring reaction 'R03657N_c_Night' since it already exists.
# Ignoring reaction 'R03658N_c_Night' since it already exists.
# Ignoring reaction 'R03659N_c_Night' since it already exists.
# Ignoring reaction 'R03660_c_Night' since it already exists.
# Ignoring reaction 'R03661_c_Night' since it already exists.
# Ignoring reaction 'R03662_c_Night' since it already exists.
# Ignoring reaction 'R03663_c_Night' since it already exists.
# Ignoring reaction 'R03664_c_Night' since it already exists.
# Ignoring reaction 'R03665_c_Night' since it already exists.
# Ignoring reaction 'R03674_c_Night' since it already exists.
# Ignoring reaction 'R03678_c_Night' since it already exists.
# Ignoring reaction 'R03719_c_Night' since it already exists.
# Ignoring reaction 'R03738_c_Night' since it already exists.
# Ignoring reaction 'R03777N_x_Night' since it already exists.
# Ignoring reaction 'R03778_x_Night' since it already exists.
# Ignoring reaction 'R03806_c_Night' since it already exists.
# Ignoring reaction 'R03807_c_Night' since it already exists.
# Ignoring reaction 'R03809_c_Night' since it already exists.
# Ignoring reaction 'R03815_c_Night' since it already exists.
# Ignoring reaction 'R03824_c_Night' since it already exists.
# Ignoring reaction 'R03845_c_Night' since it already exists.
# Ignoring reaction 'R03847_c_Night' since it already exists.
# Ignoring reaction 'R03857N_x_Night' since it already exists.
# Ignoring reaction 'R03858_x_Night' since it already exists.
# Ignoring reaction 'R03867_c_Night' since it already exists.
# Ignoring reaction 'R03869_c_Night' since it already exists.
# Ignoring reaction 'R03877_c_Night' since it already exists.
# Ignoring reaction 'R03916_c_Night' since it already exists.
# Ignoring reaction 'R03918_c_Night' since it already exists.
# Ignoring reaction 'R03919_c_Night' since it already exists.
# Ignoring reaction 'R03920_c_Night' since it already exists.
# Ignoring reaction 'R03921_c_Night' since it already exists.
# Ignoring reaction 'R03940_c_Night' since it already exists.
# Ignoring reaction 'R03943_c_Night' since it already exists.
# Ignoring reaction 'R03955_c_Night' since it already exists.
# Ignoring reaction 'R03966_c_Night' since it already exists.
# Ignoring reaction 'R03970_c_Night' since it already exists.
# Ignoring reaction 'R03971_c_Night' since it already exists.
# Ignoring reaction 'R03990N_x_Night' since it already exists.
# Ignoring reaction 'R03991_x_Night' since it already exists.
# Ignoring reaction 'R04004_c_Night' since it already exists.
# Ignoring reaction 'R04007_c_Night' since it already exists.
# Ignoring reaction 'R04008_c_Night' since it already exists.
# Ignoring reaction 'R04019_c_Night' since it already exists.
# Ignoring reaction 'R04027_c_Night' since it already exists.
# Ignoring reaction 'R04035_c_Night' since it already exists.
# Ignoring reaction 'R04037_c_Night' since it already exists.
# Ignoring reaction 'R04053_c_Night' since it already exists.
# Ignoring reaction 'R04065_c_Night' since it already exists.
# ...
# Ignoring reaction 'R00434_c_Night' since it already exists.
# Ignoring reaction 'R00507_c_Night' since it already exists.
# Ignoring reaction 'R00719_c_Night' since it already exists.
# Ignoring reaction 'R00776_c_Night' since it already exists.
# Ignoring reaction 'R00961_c_Night' since it already exists.
# Ignoring reaction 'R01054_c_Night' since it already exists.
# Ignoring reaction 'R01134_c_Night' since it already exists.
# Ignoring reaction 'R01232_c_Night' since it already exists.
# Ignoring reaction 'R01234_c_Night' since it already exists.
# Ignoring reaction 'R01244_c_Night' since it already exists.
# Ignoring reaction 'R01245_c_Night' since it already exists.
# Ignoring reaction 'R01561_c_Night' since it already exists.
# Ignoring reaction 'R01676_c_Night' since it already exists.
# Ignoring reaction 'R01677_c_Night' since it already exists.
# Ignoring reaction 'R01770_c_Night' since it already exists.
# Ignoring reaction 'R01967_c_Night' since it already exists.
# Ignoring reaction 'R01969_c_Night' since it already exists.
# Ignoring reaction 'R02143_c_Night' since it already exists.
# Ignoring reaction 'R02147_c_Night' since it already exists.
# Ignoring reaction 'R02297_c_Night' since it already exists.
# Ignoring reaction 'R02422_c_Night' since it already exists.
# Ignoring reaction 'R02425_c_Night' since it already exists.
# Ignoring reaction 'R02557_c_Night' since it already exists.
# Ignoring reaction 'R02748_c_Night' since it already exists.
# Ignoring reaction 'R02749_c_Night' since it already exists.
# Ignoring reaction 'R02805_c_Night' since it already exists.
# Ignoring reaction 'R08002_c_Night' since it already exists.
# Ignoring reaction 'R08032_c_Night' since it already exists.
# Ignoring reaction 'R08051_c_Night' since it already exists.
# Ignoring reaction 'R08052_c_Night' since it already exists.
# Ignoring reaction 'R08053_c_Night' since it already exists.
# Ignoring reaction 'R08054_c_Night' since it already exists.
# Ignoring reaction 'R08055_c_Night' since it already exists.
# Ignoring reaction 'R08075_c_Night' since it already exists.
# Ignoring reaction 'R08076_c_Night' since it already exists.
# Ignoring reaction 'R08082_c_Night' since it already exists.
# Ignoring reaction 'R08091_c_Night' since it already exists.
# Ignoring reaction 'R08093_c_Night' since it already exists.
# Ignoring reaction 'R08095_c_Night' since it already exists.
# Ignoring reaction 'R08105_c_Night' since it already exists.
# Ignoring reaction 'R08120_c_Night' since it already exists.
# Ignoring reaction 'R08121_c_Night' since it already exists.
# Ignoring reaction 'R08157_c_Night' since it already exists.
# Ignoring reaction 'R08158_c_Night' since it already exists.
# Ignoring reaction 'R08159_c_Night' since it already exists.
# Ignoring reaction 'R08161_c_Night' since it already exists.
# Ignoring reaction 'R08162_c_Night' since it already exists.
# Ignoring reaction 'R08163_c_Night' since it already exists.
# Ignoring reaction 'R08165_c_Night' since it already exists.
# Ignoring reaction 'R08174_c_Night' since it already exists.
# Ignoring reaction 'R08175_c_Night' since it already exists.
# Ignoring reaction 'R08176_c_Night' since it already exists.
# Ignoring reaction 'R08177_c_Night' since it already exists.
# Ignoring reaction 'R08178_c_Night' since it already exists.
# Ignoring reaction 'R08179_c_Night' since it already exists.
# Ignoring reaction 'R08180_c_Night' since it already exists.
# Ignoring reaction 'R08181_c_Night' since it already exists.
# Ignoring reaction 'R08182_c_Night' since it already exists.
# Ignoring reaction 'R08183_c_Night' since it already exists.
# Ignoring reaction 'R08184_c_Night' since it already exists.
# Ignoring reaction 'R08185_c_Night' since it already exists.
# Ignoring reaction 'R08186_c_Night' since it already exists.
# Ignoring reaction 'R08187_c_Night' since it already exists.
# Ignoring reaction 'R08188_c_Night' since it already exists.
# Ignoring reaction 'R08189_c_Night' since it already exists.
# Ignoring reaction 'R08190_c_Night' since it already exists.
# Ignoring reaction 'R08191_c_Night' since it already exists.
# Ignoring reaction 'R08192_c_Night' since it already exists.
# Ignoring reaction 'R08193_c_Night' since it already exists.
# Ignoring reaction 'R08221_c_Night' since it already exists.
# Ignoring reaction 'R08227_c_Night' since it already exists.
# Ignoring reaction 'R08228_c_Night' since it already exists.
# Ignoring reaction 'R08231_c_Night' since it already exists.
# Ignoring reaction 'R08233_c_Night' since it already exists.
# Ignoring reaction 'R08235_c_Night' since it already exists.
# Ignoring reaction 'R08237_c_Night' since it already exists.
# Ignoring reaction 'R08238_c_Night' since it already exists.
# Ignoring reaction 'R08240_c_Night' since it already exists.
# Ignoring reaction 'R08243_c_Night' since it already exists.
# Ignoring reaction 'R08244_c_Night' since it already exists.
# Ignoring reaction 'R08245_c_Night' since it already exists.
# Ignoring reaction 'R08266_c_Night' since it already exists.
# Ignoring reaction 'R08273_c_Night' since it already exists.
# Ignoring reaction 'R08280_c_Night' since it already exists.
# Ignoring reaction 'R08281_c_Night' since it already exists.
# Ignoring reaction 'R08306_c_Night' since it already exists.
# Ignoring reaction 'R08310_c_Night' since it already exists.
# Ignoring reaction 'R08359_c_Night' since it already exists.
# Ignoring reaction 'R08363_c_Night' since it already exists.
# Ignoring reaction 'R08364_c_Night' since it already exists.
# Ignoring reaction 'R08379_c_Night' since it already exists.
# Ignoring reaction 'R08383_c_Night' since it already exists.
# Ignoring reaction 'R07413_c_Night' since it already exists.
# Ignoring reaction 'R07429_c_Night' since it already exists.
# Ignoring reaction 'R07430_c_Night' since it already exists.
# Ignoring reaction 'R07431_c_Night' since it already exists.
# Ignoring reaction 'R07436_c_Night' since it already exists.
# Ignoring reaction 'R07437_c_Night' since it already exists.
# Ignoring reaction 'R07441_c_Night' since it already exists.
# Ignoring reaction 'R07442_c_Night' since it already exists.
# Ignoring reaction 'R07443_c_Night' since it already exists.
# Ignoring reaction 'R07444_c_Night' since it already exists.
# Ignoring reaction 'R07445_c_Night' since it already exists.
# Ignoring reaction 'R07447_c_Night' since it already exists.
# Ignoring reaction 'R07448_c_Night' since it already exists.
# Ignoring reaction 'R07449_c_Night' since it already exists.
# Ignoring reaction 'R07450_c_Night' since it already exists.
# Ignoring reaction 'R07451_c_Night' since it already exists.
# Ignoring reaction 'R07452_c_Night' since it already exists.
# Ignoring reaction 'R07453_c_Night' since it already exists.
# Ignoring reaction 'R07454_c_Night' since it already exists.
# Ignoring reaction 'R07455_c_Night' since it already exists.
# Ignoring reaction 'R07457_c_Night' since it already exists.
# Ignoring reaction 'R07458_c_Night' since it already exists.
# Ignoring reaction 'R07460_c_Night' since it already exists.
# Ignoring reaction 'R07481_c_Night' since it already exists.
# Ignoring reaction 'R07483_c_Night' since it already exists.
# Ignoring reaction 'R07484_c_Night' since it already exists.
# Ignoring reaction 'R07486_c_Night' since it already exists.
# Ignoring reaction 'R07487_c_Night' since it already exists.
# Ignoring reaction 'R07488_c_Night' since it already exists.
# Ignoring reaction 'R07489_c_Night' since it already exists.
# Ignoring reaction 'R07491_c_Night' since it already exists.
# Ignoring reaction 'R07492_c_Night' since it already exists.
# Ignoring reaction 'R07493_c_Night' since it already exists.
# Ignoring reaction 'R07498_c_Night' since it already exists.
# Ignoring reaction 'R07499_c_Night' since it already exists.
# Ignoring reaction 'R07500_c_Night' since it already exists.
# Ignoring reaction 'R07502_c_Night' since it already exists.
# Ignoring reaction 'R07503_c_Night' since it already exists.
# Ignoring reaction 'R07504_c_Night' since it already exists.
# Ignoring reaction 'R07507_c_Night' since it already exists.
# Ignoring reaction 'R07509_c_Night' since it already exists.
# Ignoring reaction 'R07530_c_Night' since it already exists.
# Ignoring reaction 'R07531_c_Night' since it already exists.
# Ignoring reaction 'R07554_c_Night' since it already exists.
# Ignoring reaction 'R07556_c_Night' since it already exists.
# Ignoring reaction 'R07558_c_Night' since it already exists.
# Ignoring reaction 'R07559_c_Night' since it already exists.
# Ignoring reaction 'R07561_c_Night' since it already exists.
# Ignoring reaction 'R07562_c_Night' since it already exists.
# Ignoring reaction 'R07568_c_Night' since it already exists.
# Ignoring reaction 'R07569_c_Night' since it already exists.
# Ignoring reaction 'R07570_c_Night' since it already exists.
# Ignoring reaction 'R07572_c_Night' since it already exists.
# Ignoring reaction 'R07599_c_Night' since it already exists.
# Ignoring reaction 'R07600_c_Night' since it already exists.
# Ignoring reaction 'R07601_c_Night' since it already exists.
# Ignoring reaction 'R07602_c_Night' since it already exists.
# Ignoring reaction 'R07603_c_Night' since it already exists.
# Ignoring reaction 'R07604_c_Night' since it already exists.
# Ignoring reaction 'R07672_c_Night' since it already exists.
# Ignoring reaction 'R07673_c_Night' since it already exists.
# Ignoring reaction 'R07674_c_Night' since it already exists.
# Ignoring reaction 'R07675_c_Night' since it already exists.
# Ignoring reaction 'R07678_c_Night' since it already exists.
# Ignoring reaction 'R07679N_c_Night' since it already exists.
# Ignoring reaction 'R07687_c_Night' since it already exists.
# Ignoring reaction 'R07688_c_Night' since it already exists.
# Ignoring reaction 'R07697_c_Night' since it already exists.
# Ignoring reaction 'R07700_c_Night' since it already exists.
# Ignoring reaction 'R07706_c_Night' since it already exists.
# Ignoring reaction 'R07759_c_Night' since it already exists.
# Ignoring reaction 'R07760_c_Night' since it already exists.
# Ignoring reaction 'R07761_c_Night' since it already exists.
# Ignoring reaction 'R07762_c_Night' since it already exists.
# Ignoring reaction 'R07763_c_Night' since it already exists.
# Ignoring reaction 'R07764_c_Night' since it already exists.
# Ignoring reaction 'R07765_c_Night' since it already exists.
# Ignoring reaction 'R07766_c_Night' since it already exists.
# Ignoring reaction 'R07767_c_Night' since it already exists.
# Ignoring reaction 'R07768_c_Night' since it already exists.
# Ignoring reaction 'R07769_c_Night' since it already exists.
# Ignoring reaction 'R07779_c_Night' since it already exists.
# Ignoring reaction 'R07804_c_Night' since it already exists.
# Ignoring reaction 'R07807_c_Night' since it already exists.
# Ignoring reaction 'R07809_c_Night' since it already exists.
# Ignoring reaction 'R07810_c_Night' since it already exists.
# Ignoring reaction 'R07816_c_Night' since it already exists.
# Ignoring reaction 'R07826_c_Night' since it already exists.
# Ignoring reaction 'R07840_c_Night' since it already exists.
# Ignoring reaction 'R07850_c_Night' since it already exists.
# Ignoring reaction 'R07851_c_Night' since it already exists.
# Ignoring reaction 'R07855_c_Night' since it already exists.
# Ignoring reaction 'R07856_c_Night' since it already exists.
# Ignoring reaction 'R07863_c_Night' since it already exists.
# Ignoring reaction 'R07864_c_Night' since it already exists.
# Ignoring reaction 'R07865_c_Night' since it already exists.
# Ignoring reaction 'R07868_c_Night' since it already exists.
# Ignoring reaction 'R07869_c_Night' since it already exists.
# Ignoring reaction 'R07870_c_Night' since it already exists.
# Ignoring reaction 'R07874_c_Night' since it already exists.
# Ignoring reaction 'R07887_c_Night' since it already exists.
# Ignoring reaction 'R07888_c_Night' since it already exists.
# Ignoring reaction 'R07889_c_Night' since it already exists.
# Ignoring reaction 'R07890_c_Night' since it already exists.
# Ignoring reaction 'R07891_c_Night' since it already exists.
# Ignoring reaction 'R07892_c_Night' since it already exists.
# Ignoring reaction 'R07893_c_Night' since it already exists.
# Ignoring reaction 'R07894_c_Night' since it already exists.
# Ignoring reaction 'R07895_c_Night' since it already exists.
# Ignoring reaction 'R07896_c_Night' since it already exists.
# Ignoring reaction 'R07897_c_Night' since it already exists.
# Ignoring reaction 'R07898_c_Night' since it already exists.
# Ignoring reaction 'R07899_c_Night' since it already exists.
# Ignoring reaction 'R07911_c_Night' since it already exists.
# Ignoring reaction 'R07916_c_Night' since it already exists.
# Ignoring reaction 'R07934_c_Night' since it already exists.
# Ignoring reaction 'R07942_c_Night' since it already exists.
# Ignoring reaction 'R07950_c_Night' since it already exists.
# Ignoring reaction 'R07977_c_Night' since it already exists.
# Ignoring reaction 'R07978_c_Night' since it already exists.
# Ignoring reaction 'R07979_c_Night' since it already exists.
# Ignoring reaction 'R07981_c_Night' since it already exists.
# Ignoring reaction 'R07987_c_Night' since it already exists.
# Ignoring reaction 'R07988_c_Night' since it already exists.
# Ignoring reaction 'R07989_c_Night' since it already exists.
# Ignoring reaction 'R07990_c_Night' since it already exists.
# Ignoring reaction 'R07993_c_Night' since it already exists.
# Ignoring reaction 'R07995_c_Night' since it already exists.
# Ignoring reaction 'R07996_c_Night' since it already exists.
# Ignoring reaction 'R07997_c_Night' since it already exists.
# Ignoring reaction 'R07998_c_Night' since it already exists.
# Ignoring reaction 'R07999_c_Night' since it already exists.
# Ignoring reaction 'R00126_c_Night' since it already exists.
# Ignoring reaction 'R00376N_c_Night' since it already exists.
# Ignoring reaction 'R00513_c_Night' since it already exists.
# Ignoring reaction 'R00516_c_Night' since it already exists.
# Ignoring reaction 'R00517_c_Night' since it already exists.
# Ignoring reaction 'R00962_c_Night' since it already exists.
# Ignoring reaction 'R00964_c_Night' since it already exists.
# Ignoring reaction 'R00967_c_Night' since it already exists.
# Ignoring reaction 'R00968_c_Night' since it already exists.
# Ignoring reaction 'R00970_c_Night' since it already exists.
# Ignoring reaction 'R00978_c_Night' since it already exists.
# Ignoring reaction 'R01415_c_Night' since it already exists.
# Ignoring reaction 'R01548_c_Night' since it already exists.
# Ignoring reaction 'R01549_c_Night' since it already exists.
# Ignoring reaction 'R01618_c_Night' since it already exists.
# Ignoring reaction 'R01666_c_Night' since it already exists.
# Ignoring reaction 'R01876_c_Night' since it already exists.
# Ignoring reaction 'R01880_c_Night' since it already exists.
# Ignoring reaction 'R02091_c_Night' since it already exists.
# Ignoring reaction 'R02096_c_Night' since it already exists.
# Ignoring reaction 'R02097_c_Night' since it already exists.
# Ignoring reaction 'R02327_c_Night' since it already exists.
# Ignoring reaction 'R02332_c_Night' since it already exists.
# Ignoring reaction 'R02371_c_Night' since it already exists.
# Ignoring reaction 'R02372_c_Night' since it already exists.
# Ignoring reaction 'R00157_c_Night' since it already exists.
# Ignoring reaction 'R00159_c_Night' since it already exists.
# Ignoring reaction 'R00514_c_Night' since it already exists.
# Ignoring reaction 'R00569_c_Night' since it already exists.
# Ignoring reaction 'R00974_c_Night' since it already exists.
# Ignoring reaction 'R01080_c_Night' since it already exists.
# Ignoring reaction 'R02092_c_Night' since it already exists.
# Ignoring reaction 'R02095_c_Night' since it already exists.
# Ignoring reaction 'R02102_c_Night' since it already exists.
# Ignoring reaction 'R02296_c_Night' since it already exists.
# Ignoring reaction 'R02484_c_Night' since it already exists.
# Ignoring reaction 'R03925_c_Night' since it already exists.
# Ignoring reaction 'R06601_c_Night' since it already exists.
# Ignoring reaction 'R06605_c_Night' since it already exists.
# Ignoring reaction 'R04457_c_Night' since it already exists.
# Ignoring reaction 'R03066_c_Night' since it already exists.
# Ignoring reaction 'R03165_c_Night' since it already exists.

# %%
cobra.io.write_sbml_model(DM, "AraGEM2010_day_night_copy.xml")

# %%
load_model = cobra.io.read_sbml_model("AraGEM2010_day_night_copy.xml")

# %%
from cobra import Model
from typing import List
from cobra import Reaction
from cobra import Metabolite


class StoragePoolCreator:
    def __init__(self, model: Model, metabolites: List[str]):
        self.model: Model = model
        self.metabolites: List[str] = metabolites

    def storage_pool(self):
        new_ids = []
        metabolite_objs = []
        names = []
        for id in self.metabolites:
            if id in self.model.metabolites:
                new_id: str = id.replace(self.model.metabolites.get_by_id(id).compartment, "sp")
                names.append(self.model.metabolites.get_by_id(id).name)
                new_ids.append(new_id)
            else:
                raise ValueError("Metabolite id not present in the model that was given.")
        for new_id in new_ids:
            metabolite = Metabolite(new_id)
            metabolite.compartment = "sp"
            metabolite_objs.append(metabolite)
        for idx, met in enumerate(metabolite_objs):
            met.name = names[idx]
        self.model.add_metabolites(metabolite_objs)
        self.model._compartments["sp"] = "Storage Pool"

# %%
test = StoragePoolCreator(load_model, ["S_Holo_45__91_carboxylase_93__c_Day","S_Homoeriodictyol_32_chalcone_c_Day", "S_Homogentisate_c_Day", "S_Hordenine_c_Day"])
test.storage_pool()

load_model.metabolites.get_by_id("S_Holo_45__91_carboxylase_93__sp")
# Out:
# <Metabolite S_Holo_45__91_carboxylase_93__sp at 0x29105b765e0>

# %%
load_model.reactions.query("Ex")
# Out:
# [<Reaction Ex1_Day at 0x29104c03430>,
#  <Reaction Ex2_Day at 0x29104c03640>,
#  <Reaction Ex3_Day at 0x29104c03610>,
#  <Reaction Ex4_Day at 0x29104c03670>,
#  <Reaction Ex5_Day at 0x29104c031f0>,
#  <Reaction Ex6_Day at 0x29104c06d30>,
#  <Reaction Ex7_Day at 0x29104c06df0>,
#  <Reaction Ex8_Day at 0x29104c06e50>,
#  <Reaction Ex9_Day at 0x29104c06f70>,
#  <Reaction Ex10_Day at 0x29104c0a520>,
#  <Reaction Ex11_Day at 0x29104c0a820>,
#  <Reaction Ex12_Day at 0x29104c0a940>,
#  <Reaction Ex13_Day at 0x29104c0aa60>,
#  <Reaction Ex14_Day at 0x29104c0adc0>,
#  <Reaction Ex15_Day at 0x29104c06f10>,
#  <Reaction Ex16_Day at 0x29104c0ad60>,
#  <Reaction Ex17_Day at 0x29104c0a3a0>,
#  <Reaction Ex18_Day at 0x29104c0afd0>,
#  <Reaction Ex1_Night at 0x291054d4430>,
#  <Reaction Ex2_Night at 0x291054d4ca0>,
#  <Reaction Ex3_Night at 0x291054d4cd0>,
#  <Reaction Ex4_Night at 0x291054d4d90>,
#  <Reaction Ex5_Night at 0x291054d4e50>,
#  <Reaction Ex6_Night at 0x291054d4f10>,
#  <Reaction Ex7_Night at 0x291054d4fd0>,
#  <Reaction Ex8_Night at 0x291054d4ee0>,
#  <Reaction Ex9_Night at 0x291054d42b0>,
#  <Reaction Ex10_Night at 0x291054d42e0>,
#  <Reaction Ex11_Night at 0x291054d4c70>,
#  <Reaction Ex12_Night at 0x291054df3d0>,
#  <Reaction Ex13_Night at 0x291054df490>,
#  <Reaction Ex14_Night at 0x291054df550>,
#  <Reaction Ex15_Night at 0x291054df610>,
#  <Reaction Ex16_Night at 0x291054df790>,
#  <Reaction Ex17_Night at 0x291054df7c0>,
#  <Reaction Ex18_Night at 0x291054df880>]
