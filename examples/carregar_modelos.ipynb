# %%
import cobra
import os
from tests import TEST_DIR

model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Rice_OSI1136.sbml'))

model
# Out:
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# Adding exchange reaction EX_met_899 with default bounds for boundary metabolite: met_899.
# Adding exchange reaction EX_PROTON with default bounds for boundary metabolite: PROTON.
# Adding exchange reaction EX_WATER with default bounds for boundary metabolite: WATER.
# Adding exchange reaction EX_x_AALANINE with default bounds for boundary metabolite: x_AALANINE.
# Adding exchange reaction EX_x_AMMONIA with default bounds for boundary metabolite: x_AMMONIA.
# Adding exchange reaction EX_x_AMP with default bounds for boundary metabolite: x_AMP.
# Adding exchange reaction EX_x_ARG with default bounds for boundary metabolite: x_ARG.
# Adding exchange reaction EX_x_ASN with default bounds for boundary metabolite: x_ASN.
# Adding exchange reaction EX_x_ASPARTATE with default bounds for boundary metabolite: x_ASPARTATE.
# ...

# %%
diel_rice_model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_rice_OSI1136_model.xml'))
# Out:
# '' is not a valid SBML 'SId'.
# No objective coefficients in model. Unclear what should be optimized

# %%
model.objective = "chl_Photon_tx"
model.objective_direction = "max"
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 chl_Photon_tx = 1000.0000000000005</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>x_Photon</td>
#       <td>EX_x_Photon</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
diel_rice_model.objective = "chl_Photon_tx_Day"
diel_rice_model.objective_direction = "max"
diel_rice_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 chl_Photon_tx_Day = 999.9999999999998</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>x_Photon_Day</td>
#       <td>EX_x_Photon_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Rice_Poolman.sbml'))

model
# Out:
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# Adding exchange reaction EX_met_1182 with default bounds for boundary metabolite: met_1182.
# Adding exchange reaction EX_PROTON with default bounds for boundary metabolite: PROTON.
# Adding exchange reaction EX_WATER with default bounds for boundary metabolite: WATER.
# Adding exchange reaction EX_x_AALANINE with default bounds for boundary metabolite: x_AALANINE.
# Adding exchange reaction EX_x_AMMONIA with default bounds for boundary metabolite: x_AMMONIA.
# Adding exchange reaction EX_x_AMP with default bounds for boundary metabolite: x_AMP.
# Adding exchange reaction EX_x_ARG with default bounds for boundary metabolite: x_ARG.
# Adding exchange reaction EX_x_ASN with default bounds for boundary metabolite: x_ASN.
# Adding exchange reaction EX_x_ASPARTATE with default bounds for boundary metabolite: x_ASPARTATE.
# ...

# %%
lista = ["SUCROSE", "SULFATE", "NITRATE", "HIS", "ILE",
                         "LEU", "LYS", "MET", "PHE", "THR", "TRP", "VAL",
                         "ARG", "CYS", "GLN", "GLY", "PRO", "TYR", "met_1117",
                         "met_1135", "ASN", "SER", "Starch_str", "FRU", "MAL",
                         "FUM", "CIT"]

for l in lista:
    model.metabolites.get_by_id(l)

# %%
diel_rice_model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_rice_poolman_model.xml'))
# Out:
# '' is not a valid SBML 'SId'.
# No objective coefficients in model. Unclear what should be optimized

# %%
model.objective = "chl_Photon_tx"
model.objective_direction = "max"
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 chl_Photon_tx = 1000.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>x_Photon</td>
#       <td>EX_x_Photon</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
diel_rice_model.objective = "chl_Photon_tx_Day"
diel_rice_model.objective_direction = "max"
diel_rice_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 chl_Photon_tx_Day = 1000.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>x_Photon_Day</td>
#       <td>EX_x_Photon_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
import cobra
import os
from tests import TEST_DIR

diel_maize_saha = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_maize_saha_model.xml'))

diel_maizeC4GEM_model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_maizeC4GEM_model.xml'))

# diel_medicago = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_medicago_model.xml'))

diel_potato = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_potato_model.xml'))

diel_rice_Lakshmanan = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_rice_Lakshmanan_model.xml'))

diel_sorghum = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_sorghum_model.xml'))

diel_sugarcane = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_sugarcane_model.xml'))

diel_thaliana2013 = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_thaliana2013_model.xml'))
# Out:
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.

# %%
diel_thaliana2013 = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_thaliana2013_model.xml'))
# Out:
# '' is not a valid SBML 'SId'.
# No objective coefficients in model. Unclear what should be optimized

# %%
thaliana2013 = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Athaliana_cheung13.xml'))
# Out:
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# Adding exchange reaction EX_PROTON_c with default bounds for boundary metabolite: PROTON_c.
# Adding exchange reaction EX_PROTON_m with default bounds for boundary metabolite: PROTON_m.
# Adding exchange reaction EX_PROTON_p with default bounds for boundary metabolite: PROTON_p.
# Adding exchange reaction EX_PROTON_v with default bounds for boundary metabolite: PROTON_v.
# Adding exchange reaction EX_PROTON_x with default bounds for boundary metabolite: PROTON_x.
# Adding exchange reaction EX_WATER_c with default bounds for boundary metabolite: WATER_c.
# Adding exchange reaction EX_WATER_m with default bounds for boundary metabolite: WATER_m.
# Adding exchange reaction EX_WATER_p with default bounds for boundary metabolite: WATER_p.
# Adding exchange reaction EX_WATER_v with default bounds for boundary metabolite: WATER_v.
# ...

# %%
diel_thaliana2013.objective = "EX_x_Photon_Day"
diel_thaliana2013.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_x_Photon_Day = 1000.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>x_Photon_Day</td>
#       <td>EX_x_Photon_Day</td>
#       <td>-1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
thaliana2013.objective = "EX_x_Photon"
thaliana2013.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_x_Photon = 1000.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>x_Photon</td>
#       <td>EX_x_Photon</td>
#       <td>-1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import cobra
import os
from tests import TEST_DIR

maize_saha = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Maize_Saha2011_v2.xml'))

maizeC4GEM_model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Maize_C4GEM_vs1.0.xml'))

potato = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'potato_mat.xml'))

rice_Lakshmanan = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Rice_Lakshmanan.xml'))

sorghum = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Sorghum_C4GEM_vs1.0.xml'))

sugarcane = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'SugarCane_C4GEM_vs1.0.xml'))

thaliana2013 = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Athaliana_cheung13.xml'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 11
#       7 maizeC4GEM_model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Maize_C4GEM_vs1.0.xml'))
#       9 potato = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'potato_mat.xml'))
# ---> 11 rice_Lakshmanan = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Rice_Lakshmanan.xml'))
#      13 sorghum = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Sorghum_C4GEM_vs1.0.xml'))
#      15 sugarcane = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'SugarCane_C4GEM_vs1.0.xml'))
#
# File ~\anaconda3\envs\diel_models\lib\site-packages\cobra\io\sbml.py:458, in read_sbml_model(filename, number, f_replace, **kwargs)
#     456 try:
#     457     doc = _get_doc_from_filename(filename)
# ...

# %%
model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Athaliana_cheung13.xml'))

# %%
import pandas as pd 

biomass_reactions = []
for reaction in model.reactions:
    if "biomass" in reaction.name:
        biomass_reactions.append(reaction.id)

biomass_rxn = cobra.Reaction("Biomass_rxn")
biomass_rxn.name = "Biomass reaction"

for reacao_id in biomass_reactions:
    reacao_individual = model.reactions.get_by_id(reacao_id)
    biomass_rxn.add_metabolites(
        {metabolito: -coeficiente for metabolito, coeficiente in reacao_individual.metabolites.items()})
    reacao_individual.knock_out()

model.add_reactions([biomass_rxn])

constraints_for_simulations_1 = pd.read_excel(os.path.join(TEST_DIR, 'models', 'constraints_for_simulations_1.xlsx'))

bounds_dict = dict(zip(constraints_for_simulations_1["Reaction"], constraints_for_simulations_1["Control"]))

for reaction, bound in bounds_dict.items():
    model.reactions.get_by_id(reaction).bounds = (bound, 1000)

for reaction in biomass_reactions:
    if reaction not in bounds_dict.keys():
        model.reactions.get_by_id(reaction).bounds = (0, 0)

constraints_for_simulations_2 = pd.read_excel(os.path.join(TEST_DIR, 'models', 'constraints_for_simulations_2.xlsx'))

for reaction, lower_bound, upper_bound in zip(constraints_for_simulations_2["Reaction"].tolist(),
                                              constraints_for_simulations_2["Minimum"].tolist(),
                                              constraints_for_simulations_2["Maximum"].tolist()):
    model.reactions.get_by_id(reaction).bounds = (lower_bound, upper_bound)

flux_1 = model.problem.Constraint(
    model.reactions.get_by_id("NO3_tx").flux_expression * 1 -
    model.reactions.get_by_id("NH4_tx").flux_expression * 1, lb=0, ub=0)
model.add_cons_vars(flux_1)

flux_2 = model.problem.Constraint(
    model.reactions.get_by_id("NADPHoxc_tx").flux_expression * 1 -
    model.reactions.get_by_id("NADPHoxp_tx").flux_expression * 1 -
    model.reactions.get_by_id("NADPHoxm_tx").flux_expression * 1, lb=0, ub=0)
model.add_cons_vars(flux_2)

model.objective = model.reactions.get_by_id("EX_x_Photon")

for compartment_id in model.compartments:
    model._compartments[compartment_id] = compartment_id

# %%
model.reactions.query("biomass")
# Out:
# [<Reaction EX_x_Cabiomass at 0x164b6001250>,
#  <Reaction EX_x_Kbiomass at 0x164b6001c10>,
#  <Reaction EX_x_Mgbiomass at 0x164b6001d90>,
#  <Reaction EX_x_NH4biomass at 0x164b5fe33d0>,
#  <Reaction EX_x_NO3biomass at 0x164b5fe3610>,
#  <Reaction EX_x_Pibiomass at 0x164b5fe39d0>,
#  <Reaction EX_x_SO4biomass at 0x164b5fe3c10>,
#  <Reaction AMP_biomass at 0x16528313d90>,
#  <Reaction ASCORBATE_biomass at 0x1652ad3ddc0>,
#  <Reaction CMP_biomass at 0x1652809cc40>,
#  <Reaction Ca_biomass at 0x165280c1bb0>,
#  <Reaction Cellulose_biomass at 0x165280c1e50>,
#  <Reaction ConOL_biomass at 0x165280c1fa0>,
#  <Reaction CoumOL_biomass at 0x165280c1f10>,
#  <Reaction FAD_biomass at 0x1652aaf0d00>,
#  <Reaction FattyAcid_biomass at 0x1652ac0bf10>,
#  <Reaction GLUTATHIONE_biomass at 0x1652af4a670>,
#  <Reaction GMP_biomass at 0x1652b0217f0>,
#  <Reaction Glycerol_biomass at 0x1652b034e80>,
#  <Reaction INDOLE_ACETATE_AUXIN_biomass at 0x1652b0a29a0>,
#  <Reaction K_biomass at 0x165281cee50>,
# ...

# %%
model.metabolites.get_by_id("x_sSER").reactions
# Out:
# frozenset({<Reaction EX_x_sSER at 0x164e8b969d0>,
#            <Reaction sSER_biomass at 0x164e9d7fe80>})

# %%
model.reactions.get_by_id("EX_x_sSER").upper_bound
# Out:
# 1000.0

# %%
model.reactions.get_by_id("Biomass_rxn").metabolites
# Out:
# {<Metabolite x_Cabiomass at 0x164ae8ec640>: 2.0,
#  <Metabolite x_Kbiomass at 0x164ae8ecfa0>: 2.0,
#  <Metabolite x_Mgbiomass at 0x164ae8ecfd0>: 2.0,
#  <Metabolite x_NH4biomass at 0x164ae8ecee0>: 2.0,
#  <Metabolite x_NO3biomass at 0x164ae8ec7c0>: 2.0,
#  <Metabolite x_Pibiomass at 0x164ae3815b0>: 2.0,
#  <Metabolite x_SO4biomass at 0x164ae3a03a0>: 2.0,
#  <Metabolite PPI_c at 0x164ae3cc5e0>: 12.0,
#  <Metabolite x_AMP at 0x164ae39aeb0>: 1.0,
#  <Metabolite met_2417 at 0x164ae3b9e80>: -4.0,
#  <Metabolite ATP_c at 0x164aea237c0>: -5.0,
#  <Metabolite x_ASCORBATE at 0x164ae39a850>: 1.0,
#  <Metabolite ASCORBATE_c at 0x164aea23d90>: -1.0,
#  <Metabolite x_CHLa at 0x164ae8ecdf0>: 1.0,
#  <Metabolite met_373 at 0x164aea0b610>: -1.0,
#  <Metabolite x_CHLb at 0x164ae8ecf40>: 1.0,
#  <Metabolite met_374 at 0x164aea0bac0>: -1.0,
#  <Metabolite x_CMP at 0x164ae8ec580>: 1.0,
#  <Metabolite CTP_c at 0x164ae954ac0>: -1.0,
#  <Metabolite x_CoA at 0x164ae8ec4f0>: 1.0,
# ...

# %%
model.objective = "EX_x_Photon"
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_x_Photon = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
diel_thaliana2013.objective = "EX_x_Photon_Day"
diel_thaliana2013.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_x_Photon_Day = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
potato.summary()
# Out:
# <h3>Objective</h3><p>1.0 RBS01 = 41.532942171754144</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Photon[e]</td>
#       <td>RB002</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrile[e]</td>
#       <td>RB003</td>
#       <td>230.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrite[e]</td>
#       <td>RB004</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>CO2[e]</td>
#       <td>RB005</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Hydrogen_sulfide[e]</td>
#       <td>RB008</td>
#       <td>465.6</td>
#       <td>0</td>
# ...

# %%
diel_potato.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Total = 82.43853360860741</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Photon[e]_Day</td>
#       <td>RB002_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrile[e]_Day</td>
#       <td>RB003_Day</td>
#       <td>247.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrile[e]_Night</td>
#       <td>RB003_Night</td>
#       <td>216.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrite[e]_Day</td>
#       <td>RB004_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrite[e]_Night</td>
#       <td>RB004_Night</td>
# ...

# %%
maize_saha.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_Biomass = 0.07996248569203822</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001_c</td>
#       <td>EX_C00001</td>
#       <td>596.2</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009_c</td>
#       <td>EX_C00009</td>
#       <td>0.1129</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011_c</td>
#       <td>EX_C00011</td>
#       <td>299.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00059_c</td>
#       <td>EX_C00059</td>
#       <td>0.2682</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00238_c</td>
#       <td>EX_C00238</td>
#       <td>2.135</td>
#       <td>0</td>
# ...

# %%
diel_maize_saha.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Total = 0.14296789169779037</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001_c_Day</td>
#       <td>EX_C00001_Day</td>
#       <td>510.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00001_c_Night</td>
#       <td>EX_C00001_Night</td>
#       <td>528.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009_c_Day</td>
#       <td>EX_C00009_Day</td>
#       <td>0.1009</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009_c_Night</td>
#       <td>EX_C00009_Night</td>
#       <td>0.1009</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011_c_Day</td>
# ...

# %%
from cobra.flux_analysis import pfba

solution = pfba(diel_maize_saha)
solution.fluxes["EX_hvo_Night"]
# Out:
# 0.0

# %%
maizeC4GEM_model.objective = "hv_total"
maizeC4GEM_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total = 1000.0000000000002</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext</td>
#       <td>EX_S_H2O_ext</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total</td>
#       <td>EX_S_hv_total</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext</td>
#       <td>EX_S_Oxygen_ext</td>
# ...

# %%
diel_maizeC4GEM_model.objective = "hv_total_Day"
diel_maizeC4GEM_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total_Day = 1000.0000000000011</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext_Day</td>
#       <td>EX_S_H2O_ext_Day</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total_Day</td>
#       <td>EX_S_hv_total_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext_Day</td>
# ...

# %%
rice_Lakshmanan.summary()
# Out:
# <h3>Objective</h3><p>1.0 Straw_Biomass = 88.2691467908005</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_DASH_L_e</td>
#       <td>EX_arg_DASH_L_LPAREN_e_RPAREN_</td>
#       <td>1.086</td>
#       <td>6</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>cys_DASH_L_e</td>
#       <td>EX_cys_DASH_L_LPAREN_e_RPAREN_</td>
#       <td>547.5</td>
#       <td>3</td>
#       <td>8.57%</td>
#     </tr>
#     <tr>
#       <td>gln_DASH_L_e</td>
#       <td>EX_gln_DASH_L_LPAREN_e_RPAREN_</td>
#       <td>63.13</td>
#       <td>5</td>
#       <td>1.65%</td>
#     </tr>
#     <tr>
#       <td>glu_DASH_L_e</td>
#       <td>EX_glu_DASH_L_LPAREN_e_RPAREN_</td>
#       <td>1000</td>
#       <td>5</td>
#       <td>26.08%</td>
#     </tr>
# ...

# %%
diel_rice_Lakshmanan.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Total = 171.7951022914265</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_DASH_L_e_Day</td>
#       <td>EX_arg_DASH_L_LPAREN_e_RPAREN__Day</td>
#       <td>1.057</td>
#       <td>6</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>arg_DASH_L_e_Night</td>
#       <td>EX_arg_DASH_L_LPAREN_e_RPAREN__Night</td>
#       <td>1.057</td>
#       <td>6</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>cys_DASH_L_e_Day</td>
#       <td>EX_cys_DASH_L_LPAREN_e_RPAREN__Day</td>
#       <td>601.6</td>
#       <td>3</td>
#       <td>4.78%</td>
#     </tr>
#     <tr>
#       <td>cys_DASH_L_e_Night</td>
#       <td>EX_cys_DASH_L_LPAREN_e_RPAREN__Night</td>
#       <td>504.3</td>
#       <td>3</td>
# ...

# %%
sorghum.objective = "hv_total"
sorghum.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total = 1000.0000000000002</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext</td>
#       <td>EX_S_H2O_ext</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total</td>
#       <td>EX_S_hv_total</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext</td>
#       <td>EX_S_Oxygen_ext</td>
# ...

# %%
diel_sorghum.objective = "hv_total_Day"
diel_sorghum.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total_Day = 1000.0000000000011</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext_Day</td>
#       <td>EX_S_H2O_ext_Day</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total_Day</td>
#       <td>EX_S_hv_total_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext_Day</td>
# ...

# %%
sugarcane.objective = "hv_total"
sugarcane.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total = 1000.0000000000002</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext</td>
#       <td>EX_S_H2O_ext</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total</td>
#       <td>EX_S_hv_total</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext</td>
#       <td>EX_S_Oxygen_ext</td>
# ...

# %%
diel_sugarcane.objective = "hv_total_Day"
diel_sugarcane.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total_Day = 1000.0000000000011</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext_Day</td>
#       <td>EX_S_H2O_ext_Day</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total_Day</td>
#       <td>EX_S_hv_total_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext_Day</td>
# ...

# %%
quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'QuercusSuberGeneralModel.xml'))

multi_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'MultiTissueQuercusModel.xml'))

diel_multi_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_multi_quercus_model.xml'))

diel_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_quercus_model.xml'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 5
#       1 quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'QuercusSuberGeneralModel.xml'))
#       3 multi_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'MultiTissueQuercusModel.xml'))
# ----> 5 diel_multi_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_multi_quercus_model.xml'))
#       7 diel_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_quercus_model.xml'))
#
# File ~\anaconda3\envs\diel_models\lib\site-packages\cobra\io\sbml.py:458, in read_sbml_model(filename, number, f_replace, **kwargs)
#     456 try:
#     457     doc = _get_doc_from_filename(filename)
# --> 458     return _sbml_to_model(doc, number=number, f_replace=f_replace, **kwargs)
#     459 except IOError as e:
#     460     raise e
#
# ...

# %%
import cobra
import os
from tests import TEST_DIR

diel_multi_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_multi_quercus_model.xml'))

# %%
diel_multi_carboxylation_day = diel_multi_quercus.reactions.get_by_id("R00024__plst_Leaf_Day")
diel_multi_oxygenation_day = diel_multi_quercus.reactions.get_by_id("R03140__plst_Leaf_Day")

same_flux = diel_multi_quercus.problem.Constraint(
    diel_multi_carboxylation_day.flux_expression * 1 -
    diel_multi_oxygenation_day.flux_expression * 3, lb=0, ub=0)
diel_multi_quercus.add_cons_vars(same_flux)

diel_multi_carboxylation_night = diel_multi_quercus.reactions.get_by_id("R00024__plst_Leaf_Night")
diel_multi_oxygenation_night = diel_multi_quercus.reactions.get_by_id("R03140__plst_Leaf_Night")

same_flux = diel_multi_quercus.problem.Constraint(
    diel_multi_carboxylation_night.flux_expression * 1 -
    diel_multi_oxygenation_night.flux_expression * 3, lb=0, ub=0)
diel_multi_quercus.add_cons_vars(same_flux)

# %%
from cobra.flux_analysis import pfba

solution = pfba(diel_multi_quercus).fluxes
solution["Biomass_Total"]
# Out:
# 0.11454444724873937

# %%
diel_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_quercus_model.xml'))

# %%
quercus.summary()

# %%
# diel_carboxylation_day = diel_quercus.reactions.get_by_id("R00024__chlo_Day")
# diel_oxygenation_day = diel_quercus.reactions.get_by_id("R03140__chlo_Day")
# 
# same_flux = diel_quercus.problem.Constraint(
#     diel_carboxylation_day.flux_expression * 1 -
#     diel_oxygenation_day.flux_expression * 3, lb=0, ub=0)
# diel_quercus.add_cons_vars(same_flux)

diel_carboxylation_night = diel_quercus.reactions.get_by_id("R00024__chlo_Night")
diel_oxygenation_night = diel_quercus.reactions.get_by_id("R03140__chlo_Night")

same_flux = diel_quercus.problem.Constraint(
    diel_carboxylation_night.flux_expression * 1 -
    diel_oxygenation_night.flux_expression * 3, lb=0, ub=0)
diel_quercus.add_cons_vars(same_flux)

# %%
from cobra.flux_analysis import pfba

solution = pfba(diel_quercus).fluxes
solution["R03140__chlo_Day"]
# Out:
# 0.0

# %%
multi_quercus.summary()

# %%
diel_multi_quercus.summary()

# %%
medicago = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'MedicagoTruncatula.xml'))

# %%
cobra.io.write_sbml_model(medicago, os.path.join(TEST_DIR, 'models', 'MedicagoTruncatula_2.xml'))

# %%
medicago_2 = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'MedicagoTruncatula_2.xml'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\diel_models\lib\site-packages\cobra\io\sbml.py:458, in read_sbml_model(filename, number, f_replace, **kwargs)
#     457     doc = _get_doc_from_filename(filename)
# --> 458     return _sbml_to_model(doc, number=number, f_replace=f_replace, **kwargs)
#     459 except IOError as e:
#
# File ~\anaconda3\envs\diel_models\lib\site-packages\cobra\io\sbml.py:713, in _sbml_to_model(doc, number, f_replace, set_missing_bounds, **kwargs)
#     711     metabolites.append(met)
# --> 713 cobra_model.add_metabolites(metabolites)
#     715 # Add exchange reactions for boundary metabolites
#
# File ~\anaconda3\envs\diel_models\lib\site-packages\cobra\core\model.py:518, in Model.add_metabolites(self, metabolite_list)
#     517 if met.id not in self.constraints:
# ...

# %%
cobra.io.sbml.validate_sbml_model(os.path.join(TEST_DIR, 'models', 'MedicagoTruncatula_2.xml'))
# Out:
# (None,
#  {'SBML_FATAL': [],
#   'SBML_ERROR': [],
#   'SBML_SCHEMA_ERROR': [],
#   'SBML_WARNING': [],
#   'COBRA_FATAL': ['Names cannot contain whitespace characters. "M\n45__FORMYL-THF_H" contains whitespace character "\n".'],
#   'COBRA_ERROR': [],
#   'COBRA_WARNING': [],
#   'COBRA_CHECK': []})

# %%
Formyl = medicago.metabolites.get_by_id("_10-FORMYL-THF_H")
Formyl.id = Formyl.id.replace("_10", "")
for reaction in Formyl.reactions:
    if "_10" in reaction.id:
        reaction.id = reaction.id.replace("_10", "")
    if "_10" in reaction.name:
        reaction.name = reaction.name.replace("_10", "")

# %%
medicago.metabolites.get_by_id("-FORMYL-THF_H")
# Out:
# <Metabolite -FORMYL-THF_H at 0x164b5938f70>

# %%
Formyl = medicago.metabolites.get_by_id("_5-FORMYL-THF_H")
Formyl.id = Formyl.id.replace("_5", "")
for reaction in Formyl.reactions:
    if "_5" in reaction.id:
        reaction.id = reaction.id.replace("_5", "")
    if "_5" in reaction.name:
        reaction.name = reaction.name.replace("_5", "")

# %%
medicago.metabolites.get_by_id("-FORMYL-THF_H")
# Out:
# <Metabolite -FORMYL-THF_H at 0x164b1dcdee0>

# %%
diel_medicago = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_medicago_model.xml'))
# Out:
# '' is not a valid SBML 'SId'.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\diel_models\lib\site-packages\cobra\io\sbml.py:458, in read_sbml_model(filename, number, f_replace, **kwargs)
#     457     doc = _get_doc_from_filename(filename)
# --> 458     return _sbml_to_model(doc, number=number, f_replace=f_replace, **kwargs)
#     459 except IOError as e:
#
# File ~\anaconda3\envs\diel_models\lib\site-packages\cobra\io\sbml.py:713, in _sbml_to_model(doc, number, f_replace, set_missing_bounds, **kwargs)
#     711     metabolites.append(met)
# --> 713 cobra_model.add_metabolites(metabolites)
#     715 # Add exchange reactions for boundary metabolites
#
# File ~\anaconda3\envs\diel_models\lib\site-packages\cobra\core\model.py:518, in Model.add_metabolites(self, metabolite_list)
#     517 if met.id not in self.constraints:
# ...

# %%
cobra.io.sbml.validate_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_medicago_model.xml'))
# Out:
# (None,
#  {'SBML_FATAL': [],
#   'SBML_ERROR': [],
#   'SBML_SCHEMA_ERROR': [],
#   'SBML_WARNING': [],
#   'COBRA_FATAL': ['Names cannot contain whitespace characters. "M\n45__FORMYL-THF_H_Day" contains whitespace character "\n".'],
#   'COBRA_ERROR': [],
#   'COBRA_WARNING': [],
#   'COBRA_CHECK': []})

# %%
from diel_models.diel_models_creator import diel_models_creator

model = diel_models_creator(medicago,
                    ["SUCROSE_C", "SULFATE_C", "NITRATE_C", "HIS_C", "ILE_C",
                     "LEU_C", "LYS_C", "MET_C", "PHE_C", "THR_C", "TRP_C", "VAL_C",
                     "ARG_C", "CYS_C", "GLN_C", "GLY_C", "PRO_C", "TYR_C", "L-ALPHA-ALANINE_C",
                     "L-GLUTAMATE-5-P_C", "ASN_C", "SER_C", "Starch_H", "FRUCTOSE-6P_C",
                     "MAL_C", "FUM_C", "CIT_C"], ["EX_Light_E"], "BiomassShoot",
                    ["EX_NITRATE_E"])

# %%
model.reactions.get_by_id("EX_Light_E_Day")
# Out:
# <Reaction EX_Light_E_Day at 0x16528462910>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Total = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
model.metabolites.query("THF_H_Day")
# Out:
# [<Metabolite _10-FORMYL-THF_H_Day at 0x16515131070>,
#  <Metabolite _5-METHYL-THF_H_Day at 0x1651531e8b0>,
#  <Metabolite METHYLENE-THF_H_Day at 0x1652802a2b0>,
#  <Metabolite THF_H_Day at 0x165280c2d90>,
#  <Metabolite _5-10-METHENYL-THF_H_Day at 0x165280c2040>,
#  <Metabolite _5-FORMYL-THF_H_Day at 0x16528392400>]

# %%
potato_model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'potato_mat.xml'))
diel_potato_model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_potato_model.xml'))

# %%
diel_carboxylation_day = diel_potato_model.reactions.get_by_id("R00024_Day")
diel_oxygenation_day = diel_potato_model.reactions.get_by_id("R03140_Day")

same_flux = diel_potato_model.problem.Constraint(
    diel_carboxylation_day.flux_expression * 1 -
    diel_oxygenation_day.flux_expression * 3, lb=0, ub=0)
diel_potato_model.add_cons_vars(same_flux)

diel_carboxylation_night = diel_potato_model.reactions.get_by_id("R00024_Night")
diel_oxygenation_night = diel_potato_model.reactions.get_by_id("R03140_Night")

same_flux = diel_potato_model.problem.Constraint(
    diel_carboxylation_night.flux_expression * 1 -
    diel_oxygenation_night.flux_expression * 3, lb=0, ub=0)
diel_potato_model.add_cons_vars(same_flux)

# %%
from cobra.flux_analysis import pfba

solution = pfba(diel_potato_model).fluxes
solution["Biomass_Total"]
# Out:
# 82.43853360860695

# %%
potato_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 RBS01 = 41.532942171754144</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Photon[e]</td>
#       <td>RB002</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrile[e]</td>
#       <td>RB003</td>
#       <td>230.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrite[e]</td>
#       <td>RB004</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>CO2[e]</td>
#       <td>RB005</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Hydrogen_sulfide[e]</td>
#       <td>RB008</td>
#       <td>465.6</td>
#       <td>0</td>
# ...

# %%
colza = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Colza_bna572_plus.xml'))
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of the species charge attribute is discouraged, use fbc:charge instead: <Species M_abut_p "(S)-2-acetyl-2-hydroxybutanoic acid">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_abut_p "(S)-2-acetyl-2-hydroxybutanoic acid">
# Use of the species charge attribute is discouraged, use fbc:charge instead: <Species M_ac_c "acetic acid">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_c "acetic acid">
# Use of the species charge attribute is discouraged, use fbc:charge instead: <Species M_ac_m "acetic acid">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_m "acetic acid">
# ...

# %%
diel_colza = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_colza_model.xml'))

# %%
populus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Populus_iPop7188.xml'))
# Out:
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cpd_15643_m "UDP-N-acetyl-beta-L-pneumosamine">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_cpd_15643_m "UDP-N-acetyl-beta-L-pneumosamine">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_nad_m "NAD">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_nad_m "NAD">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_cpd_10750_m "UDP-2-acetamido-2,6-dideoxy-beta-L-arabino-hex-4-ulose">
# ...

# %%
diel_populus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_populus_model.xml'))

# %%
soybean = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Soybean_GSMM.xml'))

# %%
diel_soybean = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_soybean_model.xml'))

# %%
tomato = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'tomato_Sl2183.xml'))

# %%
diel_tomato = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_tomato2022_model.xml'))
