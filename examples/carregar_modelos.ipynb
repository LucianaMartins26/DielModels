# %%
import cobra
import os
from tests import TEST_DIR

model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Athaliana_Poolman2009.xml'))

model

# %%
from diel_models.diel_models_creator import diel_models_creator

diel_models_creator(model, ["SUCROSE", "SULFATE", "NITRATE", "HIS", "ILE", "LEU", "LYS", "MET", "PHE", "THR", "TRP", "VAL", "ARG", "CYS", "GLN", "GLY", "PRO", "TYR", "met_762", "met_967", "ASN", "SER", "x_Starch", "FRU", "MAL", "FUM", "Citrate"], [], "", [])

# %%
model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Rice_OSI1136.sbml'))

model
# Out:
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# Adding exchange reaction EX_met_899 with default bounds for boundary metabolite: met_899.
# Adding exchange reaction EX_PROTON with default bounds for boundary metabolite: PROTON.
# Adding exchange reaction EX_WATER with default bounds for boundary metabolite: WATER.
# Adding exchange reaction EX_x_AALANINE with default bounds for boundary metabolite: x_AALANINE.
# Adding exchange reaction EX_x_AMMONIA with default bounds for boundary metabolite: x_AMMONIA.
# Adding exchange reaction EX_x_AMP with default bounds for boundary metabolite: x_AMP.
# Adding exchange reaction EX_x_ARG with default bounds for boundary metabolite: x_ARG.
# Adding exchange reaction EX_x_ASN with default bounds for boundary metabolite: x_ASN.
# Adding exchange reaction EX_x_ASPARTATE with default bounds for boundary metabolite: x_ASPARTATE.
# ...

# %%
model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Rice_Poolman.sbml'))

model
# Out:
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# Adding exchange reaction EX_met_1182 with default bounds for boundary metabolite: met_1182.
# Adding exchange reaction EX_PROTON with default bounds for boundary metabolite: PROTON.
# Adding exchange reaction EX_WATER with default bounds for boundary metabolite: WATER.
# Adding exchange reaction EX_x_AALANINE with default bounds for boundary metabolite: x_AALANINE.
# Adding exchange reaction EX_x_AMMONIA with default bounds for boundary metabolite: x_AMMONIA.
# Adding exchange reaction EX_x_AMP with default bounds for boundary metabolite: x_AMP.
# Adding exchange reaction EX_x_ARG with default bounds for boundary metabolite: x_ARG.
# Adding exchange reaction EX_x_ASN with default bounds for boundary metabolite: x_ASN.
# Adding exchange reaction EX_x_ASPARTATE with default bounds for boundary metabolite: x_ASPARTATE.
# ...

# %%
import cobra
import os
from tests import TEST_DIR

diel_maize_saha = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_maize_saha_model.xml'))

diel_maizeC4GEM_model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_maizeC4GEM_model.xml'))

# diel_medicago = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_medicago_model.xml'))

diel_potato = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_potato_model.xml'))

diel_rice_Lakshmanan = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_rice_Lakshmanan_model.xml'))

diel_sorghum = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_sorghum_model.xml'))

diel_sugarcane = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_sugarcane_model.xml'))

diel_thaliana2013 = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_thaliana2013_model.xml'))
# Out:
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.

# %%
import cobra
import os
from tests import TEST_DIR

maize_saha = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Maize_Saha2011_v2.xml'))

maizeC4GEM_model = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Maize_C4GEM_vs1.0.xml'))

potato = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'potato_mat.xml'))

rice_Lakshmanan = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Rice_Lakshmanan.xml'))

sorghum = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Sorghum_C4GEM_vs1.0.xml'))

sugarcane = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'SugarCane_C4GEM_vs1.0.xml'))

thaliana2013 = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'Athaliana_cheung13.xml'))
# Out:
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Adding exchange reaction EX_S_Acyl_45_carrier_32_protein_c with default bounds for boundary metabolite: S_Acyl_45_carrier_32_protein_c.
# Adding exchange reaction EX_S_Acyl_45_carrier_32_protein_p with default bounds for boundary metabolite: S_Acyl_45_carrier_32_protein_p.
# Adding exchange reaction EX_S_CO2_ext with default bounds for boundary metabolite: S_CO2_ext.
# Adding exchange reaction EX_S_Enzyme_32_N6_45__40_dihydrolipoyl_41_lysine_m with default bounds for boundary metabolite: S_Enzyme_32_N6_45__40_dihydrolipoyl_41_lysine_m.
# Adding exchange reaction EX_S_Glucose_ext with default bounds for boundary metabolite: S_Glucose_ext.
# Adding exchange reaction EX_S_H2O_ext with default bounds for boundary metabolite: S_H2O_ext.
# ...

# %%
thaliana2013.objective = "EX_x_Photon"
thaliana2013.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_x_Photon = 1000.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>x_Photon</td>
#       <td>EX_x_Photon</td>
#       <td>-1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
diel_thaliana2013.objective = "EX_x_Photon_Day"
diel_thaliana2013.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_x_Photon_Day = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
potato.summary()
# Out:
# <h3>Objective</h3><p>1.0 RBS01 = 41.532942171754144</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Photon[e]</td>
#       <td>RB002</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrile[e]</td>
#       <td>RB003</td>
#       <td>230.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrite[e]</td>
#       <td>RB004</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>CO2[e]</td>
#       <td>RB005</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Hydrogen_sulfide[e]</td>
#       <td>RB008</td>
#       <td>465.6</td>
#       <td>0</td>
# ...

# %%
diel_potato.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Total = 82.43853360860741</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Photon[e]_Day</td>
#       <td>RB002_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrile[e]_Day</td>
#       <td>RB003_Day</td>
#       <td>247.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrile[e]_Night</td>
#       <td>RB003_Night</td>
#       <td>216.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrite[e]_Day</td>
#       <td>RB004_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Nitrite[e]_Night</td>
#       <td>RB004_Night</td>
# ...

# %%
maize_saha.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_Biomass = 0.07996248569203822</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001_c</td>
#       <td>EX_C00001</td>
#       <td>596.2</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009_c</td>
#       <td>EX_C00009</td>
#       <td>0.1129</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011_c</td>
#       <td>EX_C00011</td>
#       <td>299.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00059_c</td>
#       <td>EX_C00059</td>
#       <td>0.2682</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00238_c</td>
#       <td>EX_C00238</td>
#       <td>2.135</td>
#       <td>0</td>
# ...

# %%
diel_maize_saha.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Total = 0.14296789169779037</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001_c_Day</td>
#       <td>EX_C00001_Day</td>
#       <td>510.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00001_c_Night</td>
#       <td>EX_C00001_Night</td>
#       <td>528.7</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009_c_Day</td>
#       <td>EX_C00009_Day</td>
#       <td>0.1009</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009_c_Night</td>
#       <td>EX_C00009_Night</td>
#       <td>0.1009</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011_c_Day</td>
# ...

# %%
maizeC4GEM_model.objective = "hv_total"
maizeC4GEM_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total = 1000.0000000000002</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext</td>
#       <td>EX_S_H2O_ext</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total</td>
#       <td>EX_S_hv_total</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext</td>
#       <td>EX_S_Oxygen_ext</td>
# ...

# %%
diel_maizeC4GEM_model.objective = "hv_total_Day"
diel_maizeC4GEM_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total_Day = 999.999999999997</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext_Day</td>
#       <td>EX_S_H2O_ext_Day</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total_Day</td>
#       <td>EX_S_hv_total_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext_Day</td>
# ...

# %%
rice_Lakshmanan.summary()
# Out:
# <h3>Objective</h3><p>1.0 Straw_Biomass = 88.2691467908005</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_DASH_L_e</td>
#       <td>EX_arg_DASH_L_LPAREN_e_RPAREN_</td>
#       <td>1.086</td>
#       <td>6</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>cys_DASH_L_e</td>
#       <td>EX_cys_DASH_L_LPAREN_e_RPAREN_</td>
#       <td>547.5</td>
#       <td>3</td>
#       <td>8.57%</td>
#     </tr>
#     <tr>
#       <td>gln_DASH_L_e</td>
#       <td>EX_gln_DASH_L_LPAREN_e_RPAREN_</td>
#       <td>63.13</td>
#       <td>5</td>
#       <td>1.65%</td>
#     </tr>
#     <tr>
#       <td>glu_DASH_L_e</td>
#       <td>EX_glu_DASH_L_LPAREN_e_RPAREN_</td>
#       <td>1000</td>
#       <td>5</td>
#       <td>26.08%</td>
#     </tr>
# ...

# %%
diel_rice_Lakshmanan.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Total = 171.7951022914265</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_DASH_L_e_Day</td>
#       <td>EX_arg_DASH_L_LPAREN_e_RPAREN__Day</td>
#       <td>1.057</td>
#       <td>6</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>arg_DASH_L_e_Night</td>
#       <td>EX_arg_DASH_L_LPAREN_e_RPAREN__Night</td>
#       <td>1.057</td>
#       <td>6</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>cys_DASH_L_e_Day</td>
#       <td>EX_cys_DASH_L_LPAREN_e_RPAREN__Day</td>
#       <td>601.6</td>
#       <td>3</td>
#       <td>4.78%</td>
#     </tr>
#     <tr>
#       <td>cys_DASH_L_e_Night</td>
#       <td>EX_cys_DASH_L_LPAREN_e_RPAREN__Night</td>
#       <td>504.3</td>
#       <td>3</td>
# ...

# %%
sorghum.objective = "hv_total"
sorghum.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total = 1000.0000000000002</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext</td>
#       <td>EX_S_H2O_ext</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total</td>
#       <td>EX_S_hv_total</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext</td>
#       <td>EX_S_Oxygen_ext</td>
# ...

# %%
diel_sorghum.objective = "hv_total_Day"
diel_sorghum.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total_Day = 999.999999999997</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext_Day</td>
#       <td>EX_S_H2O_ext_Day</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total_Day</td>
#       <td>EX_S_hv_total_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext_Day</td>
# ...

# %%
sugarcane.objective = "hv_total"
sugarcane.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total = 1000.0000000000002</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext</td>
#       <td>EX_S_H2O_ext</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total</td>
#       <td>EX_S_hv_total</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext</td>
#       <td>EX_S_Oxygen_ext</td>
# ...

# %%
diel_sugarcane.objective = "hv_total_Day"
diel_sugarcane.summary()
# Out:
# <h3>Objective</h3><p>1.0 hv_total_Day = 1000.0000000000011</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_H2O_ext_Day</td>
#       <td>EX_S_H2O_ext_Day</td>
#       <td>333.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>S_hv_total_Day</td>
#       <td>EX_S_hv_total_Day</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>S_Oxygen_ext_Day</td>
# ...

# %%
quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'QuercusSuberGeneralModel.xml'))

multi_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'MultiTissueQuercusModel.xml'))

diel_multi_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_multi_quercus_model.xml'))

diel_quercus = cobra.io.read_sbml_model(os.path.join(TEST_DIR, 'models', 'diel_quercus_model.xml'))

# %%
quercus.summary()
# Out:
# <h3>Objective</h3><p>1.0 e_Biomass_Leaf__cyto = 0.21480708187934625</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001__extr</td>
#       <td>EX_C00001__dra</td>
#       <td>5.491</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009__extr</td>
#       <td>EX_C00009__dra</td>
#       <td>0.01465</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011__extr</td>
#       <td>EX_C00011__dra</td>
#       <td>8.256</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>C00059__extr</td>
#       <td>EX_C00059__dra</td>
#       <td>0.03152</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00080__extr</td>
# ...

# %%
diel_quercus.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Total = 0.20841281243064655</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001__extr_Day</td>
#       <td>EX_C00001__dra_Day</td>
#       <td>6.591</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00007__extr_Night</td>
#       <td>EX_C00007__dra_Night</td>
#       <td>1.273</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009__extr_Day</td>
#       <td>EX_C00009__dra_Day</td>
#       <td>0.007108</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009__extr_Night</td>
#       <td>EX_C00009__dra_Night</td>
#       <td>0.007108</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
# ...

# %%
multi_quercus.summary()
# Out:
# <h3>Objective</h3><p>1.0 Total_biomass = 0.18549316646142516</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001__env</td>
#       <td>EX_C00001__dra</td>
#       <td>5.271</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009__env</td>
#       <td>EX_C00009__dra</td>
#       <td>0.008273</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011__env</td>
#       <td>EX_C00011__dra</td>
#       <td>7.809</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>C00059__env</td>
#       <td>EX_C00059__dra</td>
#       <td>0.01507</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00205__env</td>
# ...

# %%
diel_multi_quercus.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Total = 0.17729123912066724</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001__env_Day</td>
#       <td>EX_C00001__dra_Day</td>
#       <td>7.639</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00007__env_Night</td>
#       <td>EX_C00007__dra_Night</td>
#       <td>1.69</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009__env_Day</td>
#       <td>EX_C00009__dra_Day</td>
#       <td>0.003953</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009__env_Night</td>
#       <td>EX_C00009__dra_Night</td>
#       <td>0.003953</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
# ...
